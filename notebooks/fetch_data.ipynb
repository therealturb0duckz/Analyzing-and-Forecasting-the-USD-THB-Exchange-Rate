# %%
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("API_KEY")
print("API Key loaded:", bool(api_key))
# Out:
# API Key loaded: True

# %%
import requests
from datetime import datetime, timedelta 

# random check on data retrieval
url = "https://gateway.api.bot.or.th/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/" 

# the time frame of each call is 30 days
params = {
    "start_period":"2025-01-01",
    "end_period":"2025-01-31"
}

headers={
    "Authorization":f"{api_key}",
    "Accept":"application/json"
}

response = requests.get(url, headers=headers, params=params)
data = response.json()
print(response.status_code)
print(response.text)
# nice :)
# Out:
# 200
# {"result":{"timestamp":"2025-10-21 05:24:51","api":"Daily Weighted-average Interbank Exchange Rate - THB / USD","data":{"data_header":{"report_name_eng":"Rates of Exchange of Commercial Banks in Bangkok Metropolis (2002-present)","report_name_th":"อัตราแลกเปลี่ยนเฉลี่ยของธนาคารพาณิชย์ในกรุงเทพมหานคร (2545-ปัจจุบัน)","report_uoq_name_eng":"(Unit: Baht / 1 Unit of Foreign Currency)","report_uoq_name_th":"(หน่วย: บาท ต่อ 1 หน่วยเงินตราต่างประเทศ)","report_source_of_data":[{"source_of_data_eng":"Bank of Thailand","source_of_data_th":"ธนาคารแห่งประเทศไทย"}],"report_remark":[{"report_remark_eng":"Since Nov 16, 2015 the data regarding Buying Transfer Rate of PKR has been changed to Buying Rate using Foreign Exchange Rates (LSEG) with Bangkok Market Crossing.","report_remark_th":"ตั้งแต่วันที่ 16 พ.ย. 2558 ข้อมูลในอัตราซื้อเงินโอนของสกุล PKR ได้เปลี่ยนเป็นอัตราซื้อที่ใช้อัตราในตลาดต่างประเทศ (LSEG) คำนวณผ่านอัตราซื้อขายเงินดอลลาร์ สรอ. ในตลาดกรุงเทพฯ"}],"last_updated":"2025-10-20"},"data_detail":[{"period":"2025-01-31","currency_id":"USD","currency_name_th":"สหรัฐอเมริกา : ดอลลาร์ (USD)","currency_name_eng":"USA : DOLLAR (USD) ","buying_sight":"33.4092000","buying_transfer":"33.4853000","selling":"33.8042000","mid_rate":"33.6448000"},{"period":"2025-01-31","currency_id":"GBP","currency_name_th":"อังกฤษ : ปอนด์สเตอร์ลิง (GBP)","currency_name_eng":"UNITED KINGDOM : POUND STERING (GBP)","buying_sight":"41.3458000","buying_transfer":"41.4482000","selling":"42.2217000","mid_rate":"41.8350000"},{"period":"2025-01-31","currency_id":"EUR","currency_name_th":"ยูโรโซน : ยูโร (EUR)","currency_name_eng":"EURO ZONE : EURO (EUR)","buying_sight":"34.6041000","buying_transfer":"34.6845000","selling":"35.3091000","mid_rate":"34.9968000"},{"period":"2025-01-31","currency_id":"JPY","currency_name_th":"ญี่ปุ่น : เยน (100 เยน) (JPY)","currency_name_eng":"JAPAN : YEN (100 YEN) (JPY) ","buying_sight":"21.4119000","buying_transfer":"21.4908000","selling":"22.0914000","mid_rate":"21.7911000"},{"period":"2025-01-31","currency_id":"HKD","currency_name_th":"ฮ่องกง : ดอลลาร์ (HKD) ","currency_name_eng":"HONG KONG : DOLLAR (HKD)","buying_sight":"4.2719000","buying_transfer":"4.2866000","selling":"4.3520000","mid_rate":"4.3193000"},{"period":"2025-01-31","currency_id":"MYR","currency_name_th":"มาเลเซีย : ริงกิต (MYR)","currency_name_eng":"MALAYSIA : RINGGIT (MYR)","buying_sight":"7.4630000","buying_transfer":"7.5047000","selling":"7.7204000","mid_rate":"7.6126000"},{"period":"2025-01-31","currency_id":"SGD","currency_name_th":"สิงคโปร์ : ดอลลาร์ (SGD) ","currency_name_eng":"SINGAPORE : DOLLAR (SGD)","buying_sight":"24.5665000","buying_transfer":"24.6276000","selling":"25.1421000","mid_rate":"24.8849000"},{"period":"2025-01-31","currency_id":"BND","currency_name_th":"บรูไนดารุสซาลาม : ดอลลาร์ (BND)","currency_name_eng":"BRUNEI : DOLLAR (BND) ","buying_sight":"24.3800000","buying_transfer":"24.4700000","selling":"25.2239000","mid_rate":"24.8470000"},{"period":"2025-01-31","currency_id":"PHP","currency_name_th":"ฟิลิปปินส์ : เปโซ (PHP) ","currency_name_eng":"PHILIPPINES : PESO (PHP) ","buying_sight":"0.5466000","buying_transfer":"0.5524000","selling":"0.5955000","mid_rate":"0.5740000"},{"period":"2025-01-31","currency_id":"IDR","currency_name_th":"อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)","currency_name_eng":"INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)","buying_sight":"1.8879000","buying_transfer":"1.9773000","selling":"2.1709000","mid_rate":"2.0741000"},{"period":"2025-01-31","currency_id":"INR","currency_name_th":"อินเดีย : รูปี (INR) ","currency_name_eng":"INDIA : RUPEE (INR)","buying_sight":"0.3614000","buying_transfer":"0.3620000","selling":"0.4200000","mid_rate":"0.3910000"},{"period":"2025-01-31","currency_id":"CHF","currency_name_th":"สวิสเซอร์แลนด์ : ฟรังก์ (CHF)","currency_name_eng":"SWITZERLAND : FRANC (CHF) ","buying_sight":"36.6829000","buying_transfer":"36.7324000","selling":"37.3130000","mid_rate":"37.0227000"},{"period":"2025-01-31","currency_id":"AUD","c ...

# %%
data
# Out:
# {'result': {'timestamp': '2025-10-19 00:05:56',
#   'api': 'Daily Weighted-average Interbank Exchange Rate - THB / USD',
#   'data': {'data_header': {'report_name_eng': 'Rates of Exchange of Commercial Banks in Bangkok Metropolis (2002-present)',
#     'report_name_th': 'อัตราแลกเปลี่ยนเฉลี่ยของธนาคารพาณิชย์ในกรุงเทพมหานคร (2545-ปัจจุบัน)',
#     'report_uoq_name_eng': '(Unit: Baht / 1 Unit of Foreign Currency)',
#     'report_uoq_name_th': '(หน่วย: บาท ต่อ 1 หน่วยเงินตราต่างประเทศ)',
#     'report_source_of_data': [{'source_of_data_eng': 'Bank of Thailand',
#       'source_of_data_th': 'ธนาคารแห่งประเทศไทย'}],
#     'report_remark': [{'report_remark_eng': 'Since Nov 16, 2015 the data regarding Buying Transfer Rate of PKR has been changed to Buying Rate using Foreign Exchange Rates (LSEG) with Bangkok Market Crossing.',
#       'report_remark_th': 'ตั้งแต่วันที่ 16 พ.ย. 2558 ข้อมูลในอัตราซื้อเงินโอนของสกุล PKR ได้เปลี่ยนเป็นอัตราซื้อที่ใช้อัตราในตลาดต่างประเทศ (LSEG) คำนวณผ่านอัตราซื้อขายเงินดอลลาร์ สรอ. ในตลาดกรุงเทพฯ'}],
#     'last_updated': '2025-10-17'},
#    'data_detail': [{'period': '2025-01-31',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '33.4092000',
#      'buying_transfer': '33.4853000',
#      'selling': '33.8042000',
#      'mid_rate': '33.6448000'},
#     {'period': '2025-01-31',
#      'currency_id': 'GBP',
#      'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#      'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#      'buying_sight': '41.3458000',
#      'buying_transfer': '41.4482000',
#      'selling': '42.2217000',
#      'mid_rate': '41.8350000'},
#     {'period': '2025-01-31',
#      'currency_id': 'EUR',
#      'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#      'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#      'buying_sight': '34.6041000',
#      'buying_transfer': '34.6845000',
#      'selling': '35.3091000',
#      'mid_rate': '34.9968000'},
#     {'period': '2025-01-31',
#      'currency_id': 'JPY',
#      'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#      'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#      'buying_sight': '21.4119000',
#      'buying_transfer': '21.4908000',
#      'selling': '22.0914000',
#      'mid_rate': '21.7911000'},
#     {'period': '2025-01-31',
#      'currency_id': 'HKD',
#      'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#      'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#      'buying_sight': '4.2719000',
#      'buying_transfer': '4.2866000',
#      'selling': '4.3520000',
#      'mid_rate': '4.3193000'},
#     {'period': '2025-01-31',
#      'currency_id': 'MYR',
#      'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#      'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#      'buying_sight': '7.4630000',
#      'buying_transfer': '7.5047000',
#      'selling': '7.7204000',
#      'mid_rate': '7.6126000'},
#     {'period': '2025-01-31',
#      'currency_id': 'SGD',
#      'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#      'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#      'buying_sight': '24.5665000',
#      'buying_transfer': '24.6276000',
#      'selling': '25.1421000',
#      'mid_rate': '24.8849000'},
#     {'period': '2025-01-31',
#      'currency_id': 'BND',
#      'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#      'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#      'buying_sight': '24.3800000',
#      'buying_transfer': '24.4700000',
#      'selling': '25.2239000',
#      'mid_rate': '24.8470000'},
#     {'period': '2025-01-31',
#      'currency_id': 'PHP',
#      'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#      'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#      'buying_sight': '0.5466000',
#      'buying_transfer': '0.5524000',
#      'selling': '0.5955000',
#      'mid_rate': '0.5740000'},
#     {'period': '2025-01-31',
#      'currency_id': 'IDR',
#      'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#      'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#      'buying_sight': '1.8879000',
#      'buying_transfer': '1.9773000',
#      'selling': '2.1709000',
#      'mid_rate': '2.0741000'},
#     {'period': '2025-01-31',
#      'currency_id': 'INR',
#      'currency_name_th': 'อินเดีย : รูปี (INR) ',
#      'currency_name_eng': 'INDIA : RUPEE (INR)',
#      'buying_sight': '0.3614000',
#      'buying_transfer': '0.3620000',
#      'selling': '0.4200000',
#      'mid_rate': '0.3910000'},
#     {'period': '2025-01-31',
#      'currency_id': 'CHF',
#      'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#      'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#      'buying_sight': '36.6829000',
#      'buying_transfer': '36.7324000',
#      'selling': '37.3130000',
#      'mid_rate': '37.0227000'},
#     {'period': '2025-01-31',
#      'currency_id': 'AUD',
#      'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#      'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#      'buying_sight': '20.5368000',
#      'buying_transfer': '20.5718000',
#      'selling': '21.3222000',
#      'mid_rate': '20.9470000'},
#     {'period': '2025-01-31',
#      'currency_id': 'NZD',
#      'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#      'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#      'buying_sight': '18.6671000',
#      'buying_transfer': '18.7272000',
#      'selling': '19.3043000',
#      'mid_rate': '19.0158000'},
#     {'period': '2025-01-31',
#      'currency_id': 'CAD',
#      'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#      'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#      'buying_sight': '23.0194000',
#      'buying_transfer': '23.0748000',
#      'selling': '23.4955000',
#      'mid_rate': '23.2852000'},
#     {'period': '2025-01-31',
#      'currency_id': 'SEK',
#      'currency_name_th': 'สวีเดน : โครนา (SEK)',
#      'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#      'buying_sight': '3.0139000',
#      'buying_transfer': '3.0262000',
#      'selling': '3.0792000',
#      'mid_rate': '3.0527000'},
#     {'period': '2025-01-31',
#      'currency_id': 'DKK',
#      'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#      'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#      'buying_sight': '4.6479000',
#      'buying_transfer': '4.6604000',
#      'selling': '4.7260000',
#      'mid_rate': '4.6932000'},
#     {'period': '2025-01-31',
#      'currency_id': 'NOK',
#      'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#      'currency_name_eng': 'NORWAY : KRONE (NOK)',
#      'buying_sight': '2.9365000',
#      'buying_transfer': '2.9477000',
#      'selling': '3.0045000',
#      'mid_rate': '2.9761000'},
#     {'period': '2025-01-31',
#      'currency_id': 'CNY',
#      'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#      'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#      'buying_sight': '4.5543000',
#      'buying_transfer': '4.5736000',
#      'selling': '4.6716000',
#      'mid_rate': '4.6226000'},
#     {'period': '2025-01-30',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '33.5611000',
#      'buying_transfer': '33.6210000',
#      'selling': '33.9338000',
#      'mid_rate': '33.7774000'},
#     {'period': '2025-01-30',
#      'currency_id': 'GBP',
#      'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#      'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#      'buying_sight': '41.5432000',
#      'buying_transfer': '41.6436000',
#      'selling': '42.4391000',
#      'mid_rate': '42.0414000'},
#     {'period': '2025-01-30',
#      'currency_id': 'EUR',
#      'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#      'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#      'buying_sight': '34.8185000',
#      'buying_transfer': '34.8915000',
#      'selling': '35.5482000',
#      'mid_rate': '35.2199000'},
#     {'period': '2025-01-30',
#      'currency_id': 'JPY',
#      'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#      'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#      'buying_sight': '21.4332000',
#      'buying_transfer': '21.4999000',
#      'selling': '22.1343000',
#      'mid_rate': '21.8171000'},
#     {'period': '2025-01-30',
#      'currency_id': 'HKD',
#      'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#      'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#      'buying_sight': '4.2972000',
#      'buying_transfer': '4.3106000',
#      'selling': '4.3622000',
#      'mid_rate': '4.3364000'},
#     {'period': '2025-01-30',
#      'currency_id': 'MYR',
#      'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#      'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#      'buying_sight': '7.5576000',
#      'buying_transfer': '7.5806000',
#      'selling': '7.8010000',
#      'mid_rate': '7.6908000'},
#     {'period': '2025-01-30',
#      'currency_id': 'SGD',
#      'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#      'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#      'buying_sight': '24.7004000',
#      'buying_transfer': '24.7459000',
#      'selling': '25.2820000',
#      'mid_rate': '25.0140000'},
#     {'period': '2025-01-30',
#      'currency_id': 'BND',
#      'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#      'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#      'buying_sight': '24.5547000',
#      'buying_transfer': '24.6447000',
#      'selling': '25.4053000',
#      'mid_rate': '25.0250000'},
#     {'period': '2025-01-30',
#      'currency_id': 'PHP',
#      'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#      'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#      'buying_sight': '0.5485000',
#      'buying_transfer': '0.5537000',
#      'selling': '0.5993000',
#      'mid_rate': '0.5765000'},
#     {'period': '2025-01-30',
#      'currency_id': 'IDR',
#      'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#      'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#      'buying_sight': '1.8749000',
#      'buying_transfer': '1.9795000',
#      'selling': '2.1978000',
#      'mid_rate': '2.0887000'},
#     {'period': '2025-01-30',
#      'currency_id': 'INR',
#      'currency_name_th': 'อินเดีย : รูปี (INR) ',
#      'currency_name_eng': 'INDIA : RUPEE (INR)',
#      'buying_sight': '0.3642000',
#      'buying_transfer': '0.3645000',
#      'selling': '0.4204000',
#      'mid_rate': '0.3925000'},
#     {'period': '2025-01-30',
#      'currency_id': 'CHF',
#      'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#      'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#      'buying_sight': '36.9202000',
#      'buying_transfer': '36.9898000',
#      'selling': '37.5996000',
#      'mid_rate': '37.2947000'},
#     {'period': '2025-01-30',
#      'currency_id': 'AUD',
#      'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#      'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#      'buying_sight': '20.6332000',
#      'buying_transfer': '20.6795000',
#      'selling': '21.4587000',
#      'mid_rate': '21.0691000'},
#     {'period': '2025-01-30',
#      'currency_id': 'NZD',
#      'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#      'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#      'buying_sight': '18.7837000',
#      'buying_transfer': '18.8287000',
#      'selling': '19.4195000',
#      'mid_rate': '19.1241000'},
#     {'period': '2025-01-30',
#      'currency_id': 'CAD',
#      'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#      'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#      'buying_sight': '23.2001000',
#      'buying_transfer': '23.2569000',
#      'selling': '23.7069000',
#      'mid_rate': '23.4819000'},
#     {'period': '2025-01-30',
#      'currency_id': 'SEK',
#      'currency_name_th': 'สวีเดน : โครนา (SEK)',
#      'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#      'buying_sight': '3.0368000',
#      'buying_transfer': '3.0484000',
#      'selling': '3.0960000',
#      'mid_rate': '3.0722000'},
#     {'period': '2025-01-30',
#      'currency_id': 'DKK',
#      'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#      'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#      'buying_sight': '4.6828000',
#      'buying_transfer': '4.6943000',
#      'selling': '4.7503000',
#      'mid_rate': '4.7223000'},
#     {'period': '2025-01-30',
#      'currency_id': 'NOK',
#      'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#      'currency_name_eng': 'NORWAY : KRONE (NOK)',
#      'buying_sight': '2.9541000',
#      'buying_transfer': '2.9646000',
#      'selling': '3.0148000',
#      'mid_rate': '2.9897000'},
#     {'period': '2025-01-30',
#      'currency_id': 'CNY',
#      'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#      'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#      'buying_sight': '4.6005000',
#      'buying_transfer': '4.6081000',
#      'selling': '4.6962000',
#      'mid_rate': '4.6522000'},
#     {'period': '2025-01-29',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '33.5344000',
#      'buying_transfer': '33.6150000',
#      'selling': '33.9397000',
#      'mid_rate': '33.7774000'},
#     {'period': '2025-01-29',
#      'currency_id': 'GBP',
#      'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#      'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#      'buying_sight': '41.5119000',
#      'buying_transfer': '41.6327000',
#      'selling': '42.4517000',
#      'mid_rate': '42.0422000'},
#     {'period': '2025-01-29',
#      'currency_id': 'EUR',
#      'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#      'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#      'buying_sight': '34.7989000',
#      'buying_transfer': '34.8899000',
#      'selling': '35.5745000',
#      'mid_rate': '35.2322000'},
#     {'period': '2025-01-29',
#      'currency_id': 'JPY',
#      'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#      'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#      'buying_sight': '21.3209000',
#      'buying_transfer': '21.4139000',
#      'selling': '22.0633000',
#      'mid_rate': '21.7386000'},
#     {'period': '2025-01-29',
#      'currency_id': 'HKD',
#      'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#      'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#      'buying_sight': '4.2845000',
#      'buying_transfer': '4.2992000',
#      'selling': '4.3762000',
#      'mid_rate': '4.3377000'},
#     {'period': '2025-01-29',
#      'currency_id': 'MYR',
#      'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#      'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#      'buying_sight': '7.5356000',
#      'buying_transfer': '7.5801000',
#      'selling': '7.8010000',
#      'mid_rate': '7.6906000'},
#     {'period': '2025-01-29',
#      'currency_id': 'SGD',
#      'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#      'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#      'buying_sight': '24.6658000',
#      'buying_transfer': '24.7323000',
#      'selling': '25.2934000',
#      'mid_rate': '25.0129000'},
#     {'period': '2025-01-29',
#      'currency_id': 'BND',
#      'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#      'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#      'buying_sight': '24.5279000',
#      'buying_transfer': '24.6179000',
#      'selling': '25.3759000',
#      'mid_rate': '24.9969000'},
#     {'period': '2025-01-29',
#      'currency_id': 'PHP',
#      'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#      'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#      'buying_sight': '0.5473000',
#      'buying_transfer': '0.5538000',
#      'selling': '0.5968000',
#      'mid_rate': '0.5753000'},
#     {'period': '2025-01-29',
#      'currency_id': 'IDR',
#      'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#      'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#      'buying_sight': '1.9117000',
#      'buying_transfer': '1.9938000',
#      'selling': '2.1966000',
#      'mid_rate': '2.0952000'},
#     {'period': '2025-01-29',
#      'currency_id': 'INR',
#      'currency_name_th': 'อินเดีย : รูปี (INR) ',
#      'currency_name_eng': 'INDIA : RUPEE (INR)',
#      'buying_sight': '0.3581000',
#      'buying_transfer': '0.3606000',
#      'selling': '0.4224000',
#      'mid_rate': '0.3915000'},
#     {'period': '2025-01-29',
#      'currency_id': 'CHF',
#      'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#      'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#      'buying_sight': '36.9664000',
#      'buying_transfer': '37.0546000',
#      'selling': '37.6813000',
#      'mid_rate': '37.3680000'},
#     {'period': '2025-01-29',
#      'currency_id': 'AUD',
#      'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#      'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#      'buying_sight': '20.6139000',
#      'buying_transfer': '20.6743000',
#      'selling': '21.4675000',
#      'mid_rate': '21.0709000'},
#     {'period': '2025-01-29',
#      'currency_id': 'NZD',
#      'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#      'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#      'buying_sight': '18.7560000',
#      'buying_transfer': '18.8195000',
#      'selling': '19.4411000',
#      'mid_rate': '19.1303000'},
#     {'period': '2025-01-29',
#      'currency_id': 'CAD',
#      'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#      'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#      'buying_sight': '23.1569000',
#      'buying_transfer': '23.2276000',
#      'selling': '23.7036000',
#      'mid_rate': '23.4656000'},
#     {'period': '2025-01-29',
#      'currency_id': 'SEK',
#      'currency_name_th': 'สวีเดน : โครนา (SEK)',
#      'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#      'buying_sight': '3.0263000',
#      'buying_transfer': '3.0420000',
#      'selling': '3.1041000',
#      'mid_rate': '3.0731000'},
#     {'period': '2025-01-29',
#      'currency_id': 'DKK',
#      'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#      'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#      'buying_sight': '4.6704000',
#      'buying_transfer': '4.6855000',
#      'selling': '4.7661000',
#      'mid_rate': '4.7258000'},
#     {'period': '2025-01-29',
#      'currency_id': 'NOK',
#      'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#      'currency_name_eng': 'NORWAY : KRONE (NOK)',
#      'buying_sight': '2.9455000',
#      'buying_transfer': '2.9581000',
#      'selling': '3.0256000',
#      'mid_rate': '2.9919000'},
#     {'period': '2025-01-29',
#      'currency_id': 'CNY',
#      'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#      'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#      'buying_sight': '4.5641000',
#      'buying_transfer': '4.5908000',
#      'selling': '4.7138000',
#      'mid_rate': '4.6523000'},
#     {'period': '2025-01-28',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '33.6251000',
#      'buying_transfer': '33.7090000',
#      'selling': '34.0311000',
#      'mid_rate': '33.8701000'},
#     {'period': '2025-01-28',
#      'currency_id': 'GBP',
#      'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#      'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#      'buying_sight': '41.6321000',
#      'buying_transfer': '41.7565000',
#      'selling': '42.5551000',
#      'mid_rate': '42.1558000'},
#     {'period': '2025-01-28',
#      'currency_id': 'EUR',
#      'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#      'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#      'buying_sight': '34.9540000',
#      'buying_transfer': '35.0327000',
#      'selling': '35.7140000',
#      'mid_rate': '35.3734000'},
#     {'period': '2025-01-28',
#      'currency_id': 'JPY',
#      'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#      'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#      'buying_sight': '21.3712000',
#      'buying_transfer': '21.4562000',
#      'selling': '22.0972000',
#      'mid_rate': '21.7767000'},
#     {'period': '2025-01-28',
#      'currency_id': 'HKD',
#      'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#      'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#      'buying_sight': '4.2970000',
#      'buying_transfer': '4.3133000',
#      'selling': '4.3860000',
#      'mid_rate': '4.3497000'},
#     {'period': '2025-01-28',
#      'currency_id': 'MYR',
#      'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#      'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#      'buying_sight': '7.5564000',
#      'buying_transfer': '7.5976000',
#      'selling': '7.8216000',
#      'mid_rate': '7.7096000'},
#     {'period': '2025-01-28',
#      'currency_id': 'SGD',
#      'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#      'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#      'buying_sight': '24.7499000',
#      'buying_transfer': '24.8118000',
#      'selling': '25.3668000',
#      'mid_rate': '25.0893000'},
#     {'period': '2025-01-28',
#      'currency_id': 'BND',
#      'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#      'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#      'buying_sight': '24.6093000',
#      'buying_transfer': '24.6993000',
#      'selling': '25.4558000',
#      'mid_rate': '25.0776000'},
#     {'period': '2025-01-28',
#      'currency_id': 'PHP',
#      'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#      'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#      'buying_sight': '0.5493000',
#      'buying_transfer': '0.5542000',
#      'selling': '0.6020000',
#      'mid_rate': '0.5781000'},
#     {'period': '2025-01-28',
#      'currency_id': 'IDR',
#      'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#      'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#      'buying_sight': '1.9368000',
#      'buying_transfer': '2.0102000',
#      'selling': '2.2006000',
#      'mid_rate': '2.1054000'},
#     {'period': '2025-01-28',
#      'currency_id': 'INR',
#      'currency_name_th': 'อินเดีย : รูปี (INR) ',
#      'currency_name_eng': 'INDIA : RUPEE (INR)',
#      'buying_sight': '0.3593000',
#      'buying_transfer': '0.3655000',
#      'selling': '0.4205000',
#      'mid_rate': '0.3930000'},
#     {'period': '2025-01-28',
#      'currency_id': 'CHF',
#      'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#      'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#      'buying_sight': '37.0225000',
#      'buying_transfer': '37.1031000',
#      'selling': '37.7528000',
#      'mid_rate': '37.4280000'},
#     {'period': '2025-01-28',
#      'currency_id': 'AUD',
#      'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#      'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#      'buying_sight': '20.7711000',
#      'buying_transfer': '20.8237000',
#      'selling': '21.6182000',
#      'mid_rate': '21.2210000'},
#     {'period': '2025-01-28',
#      'currency_id': 'NZD',
#      'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#      'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#      'buying_sight': '18.8435000',
#      'buying_transfer': '18.9059000',
#      'selling': '19.5224000',
#      'mid_rate': '19.2142000'},
#     {'period': '2025-01-28',
#      'currency_id': 'CAD',
#      'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#      'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#      'buying_sight': '23.2392000',
#      'buying_transfer': '23.2966000',
#      'selling': '23.7756000',
#      'mid_rate': '23.5361000'},
#     {'period': '2025-01-28',
#      'currency_id': 'SEK',
#      'currency_name_th': 'สวีเดน : โครนา (SEK)',
#      'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#      'buying_sight': '3.0400000',
#      'buying_transfer': '3.0548000',
#      'selling': '3.1132000',
#      'mid_rate': '3.0840000'},
#     {'period': '2025-01-28',
#      'currency_id': 'DKK',
#      'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#      'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#      'buying_sight': '4.6918000',
#      'buying_transfer': '4.7063000',
#      'selling': '4.7828000',
#      'mid_rate': '4.7446000'},
#     {'period': '2025-01-28',
#      'currency_id': 'NOK',
#      'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#      'currency_name_eng': 'NORWAY : KRONE (NOK)',
#      'buying_sight': '2.9595000',
#      'buying_transfer': '2.9714000',
#      'selling': '3.0340000',
#      'mid_rate': '3.0027000'},
#     {'period': '2025-01-28',
#      'currency_id': 'CNY',
#      'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#      'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#      'buying_sight': '4.5823000',
#      'buying_transfer': '4.6050000',
#      'selling': '4.7177000',
#      'mid_rate': '4.6614000'},
#     {'period': '2025-01-27',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '33.4561000',
#      'buying_transfer': '33.5507000',
#      'selling': '33.8757000',
#      'mid_rate': '33.7132000'},
#     {'period': '2025-01-27',
#      'currency_id': 'GBP',
#      'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#      'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#      'buying_sight': '41.4056000',
#      'buying_transfer': '41.5625000',
#      'selling': '42.3930000',
#      'mid_rate': '41.9778000'},
#     {'period': '2025-01-27',
#      'currency_id': 'EUR',
#      'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#      'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#      'buying_sight': '34.8020000',
#      'buying_transfer': '34.9063000',
#      'selling': '35.6201000',
#      'mid_rate': '35.2632000'},
#     {'period': '2025-01-27',
#      'currency_id': 'JPY',
#      'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#      'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#      'buying_sight': '21.2223000',
#      'buying_transfer': '21.3263000',
#      'selling': '22.0016000',
#      'mid_rate': '21.6640000'},
#     {'period': '2025-01-27',
#      'currency_id': 'HKD',
#      'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#      'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#      'buying_sight': '4.2689000',
#      'buying_transfer': '4.2849000',
#      'selling': '4.3726000',
#      'mid_rate': '4.3288000'},
#     {'period': '2025-01-27',
#      'currency_id': 'MYR',
#      'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#      'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#      'buying_sight': '7.5613000',
#      'buying_transfer': '7.6024000',
#      'selling': '7.8169000',
#      'mid_rate': '7.7097000'},
#     {'period': '2025-01-27',
#      'currency_id': 'SGD',
#      'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#      'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#      'buying_sight': '24.6480000',
#      'buying_transfer': '24.7180000',
#      'selling': '25.3059000',
#      'mid_rate': '25.0120000'},
#     {'period': '2025-01-27',
#      'currency_id': 'BND',
#      'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#      'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#      'buying_sight': '24.5611000',
#      'buying_transfer': '24.6511000',
#      'selling': '25.4081000',
#      'mid_rate': '25.0296000'},
#     {'period': '2025-01-27',
#      'currency_id': 'PHP',
#      'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#      'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#      'buying_sight': '0.5478000',
#      'buying_transfer': '0.5524000',
#      'selling': '0.5985000',
#      'mid_rate': '0.5755000'},
#     {'period': '2025-01-27',
#      'currency_id': 'IDR',
#      'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#      'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#      'buying_sight': '1.9085000',
#      'buying_transfer': '1.9944000',
#      'selling': '2.1902000',
#      'mid_rate': '2.0923000'},
#     {'period': '2025-01-27',
#      'currency_id': 'INR',
#      'currency_name_th': 'อินเดีย : รูปี (INR) ',
#      'currency_name_eng': 'INDIA : RUPEE (INR)',
#      'buying_sight': '0.3606000',
#      'buying_transfer': '0.3622000',
#      'selling': '0.4201000',
#      'mid_rate': '0.3912000'},
#     {'period': '2025-01-27',
#      'currency_id': 'CHF',
#      'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#      'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#      'buying_sight': '36.7505000',
#      'buying_transfer': '36.8586000',
#      'selling': '37.5172000',
#      'mid_rate': '37.1879000'},
#     {'period': '2025-01-27',
#      'currency_id': 'AUD',
#      'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#      'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#      'buying_sight': '20.6998000',
#      'buying_transfer': '20.7777000',
#      'selling': '21.6053000',
#      'mid_rate': '21.1915000'},
#     {'period': '2025-01-27',
#      'currency_id': 'NZD',
#      'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#      'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#      'buying_sight': '18.7836000',
#      'buying_transfer': '18.8464000',
#      'selling': '19.4959000',
#      'mid_rate': '19.1712000'},
#     {'period': '2025-01-27',
#      'currency_id': 'CAD',
#      'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#      'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#      'buying_sight': '23.1050000',
#      'buying_transfer': '23.1832000',
#      'selling': '23.6936000',
#      'mid_rate': '23.4384000'},
#     {'period': '2025-01-27',
#      'currency_id': 'SEK',
#      'currency_name_th': 'สวีเดน : โครนา (SEK)',
#      'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#      'buying_sight': '3.0206000',
#      'buying_transfer': '3.0382000',
#      'selling': '3.1089000',
#      'mid_rate': '3.0736000'},
#     {'period': '2025-01-27',
#      'currency_id': 'DKK',
#      'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#      'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#      'buying_sight': '4.6631000',
#      'buying_transfer': '4.6806000',
#      'selling': '4.7796000',
#      'mid_rate': '4.7301000'},
#     {'period': '2025-01-27',
#      'currency_id': 'NOK',
#      'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#      'currency_name_eng': 'NORWAY : KRONE (NOK)',
#      'buying_sight': '2.9449000',
#      'buying_transfer': '2.9585000',
#      'selling': '3.0351000',
#      'mid_rate': '2.9968000'},
#     {'period': '2025-01-27',
#      'currency_id': 'CNY',
#      'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#      'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#      'buying_sight': '4.5368000',
#      'buying_transfer': '4.5726000',
#      'selling': '4.7168000',
#      'mid_rate': '4.6447000'},
#     {'period': '2025-01-24',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '33.6055000',
#      'buying_transfer': '33.6866000',
#      'selling': '34.0252000',
#      'mid_rate': '33.8559000'},
#     {'period': '2025-01-24',
#      'currency_id': 'GBP',
#      'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#      'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#      'buying_sight': '41.3165000',
#      'buying_transfer': '41.4405000',
#      'selling': '42.2538000',
#      'mid_rate': '41.8472000'},
#     {'period': '2025-01-24',
#      'currency_id': 'EUR',
#      'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#      'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#      'buying_sight': '34.8594000',
#      'buying_transfer': '34.9532000',
#      'selling': '35.6373000',
#      'mid_rate': '35.2953000'},
#     {'period': '2025-01-24',
#      'currency_id': 'JPY',
#      'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#      'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#      'buying_sight': '21.3072000',
#      'buying_transfer': '21.4030000',
#      'selling': '22.0459000',
#      'mid_rate': '21.7245000'},
#     {'period': '2025-01-24',
#      'currency_id': 'HKD',
#      'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#      'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#      'buying_sight': '4.2953000',
#      'buying_transfer': '4.3101000',
#      'selling': '4.3866000',
#      'mid_rate': '4.3484000'},
#     {'period': '2025-01-24',
#      'currency_id': 'MYR',
#      'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#      'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#      'buying_sight': '7.5111000',
#      'buying_transfer': '7.5520000',
#      'selling': '7.7699000',
#      'mid_rate': '7.6610000'},
#     {'period': '2025-01-24',
#      'currency_id': 'SGD',
#      'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#      'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#      'buying_sight': '24.6821000',
#      'buying_transfer': '24.7499000',
#      'selling': '25.3106000',
#      'mid_rate': '25.0303000'},
#     {'period': '2025-01-24',
#      'currency_id': 'BND',
#      'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#      'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#      'buying_sight': '24.5576000',
#      'buying_transfer': '24.6476000',
#      'selling': '25.4074000',
#      'mid_rate': '25.0275000'},
#     {'period': '2025-01-24',
#      'currency_id': 'PHP',
#      'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#      'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#      'buying_sight': '0.5483000',
#      'buying_transfer': '0.5529000',
#      'selling': '0.5987000',
#      'mid_rate': '0.5758000'},
#     {'period': '2025-01-24',
#      'currency_id': 'IDR',
#      'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#      'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#      'buying_sight': '1.9207000',
#      'buying_transfer': '1.9959000',
#      'selling': '2.1891000',
#      'mid_rate': '2.0925000'},
#     {'period': '2025-01-24',
#      'currency_id': 'INR',
#      'currency_name_th': 'อินเดีย : รูปี (INR) ',
#      'currency_name_eng': 'INDIA : RUPEE (INR)',
#      'buying_sight': '0.3600000',
#      'buying_transfer': '0.3620000',
#      'selling': '0.4222000',
#      'mid_rate': '0.3921000'},
#     {'period': '2025-01-24',
#      'currency_id': 'CHF',
#      'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#      'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#      'buying_sight': '36.9470000',
#      'buying_transfer': '37.0376000',
#      'selling': '37.6638000',
#      'mid_rate': '37.3507000'},
#     {'period': '2025-01-24',
#      'currency_id': 'AUD',
#      'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#      'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#      'buying_sight': '20.8323000',
#      'buying_transfer': '20.9008000',
#      'selling': '21.6936000',
#      'mid_rate': '21.2972000'},
#     {'period': '2025-01-24',
#      'currency_id': 'NZD',
#      'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#      'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#      'buying_sight': '18.8775000',
#      'buying_transfer': '18.9386000',
#      'selling': '19.5579000',
#      'mid_rate': '19.2483000'},
#     {'period': '2025-01-24',
#      'currency_id': 'CAD',
#      'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#      'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#      'buying_sight': '23.2581000',
#      'buying_transfer': '23.3270000',
#      'selling': '23.8035000',
#      'mid_rate': '23.5653000'},
#     {'period': '2025-01-24',
#      'currency_id': 'SEK',
#      'currency_name_th': 'สวีเดน : โครนา (SEK)',
#      'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#      'buying_sight': '3.0346000',
#      'buying_transfer': '3.0491000',
#      'selling': '3.1089000',
#      'mid_rate': '3.0790000'},
#     {'period': '2025-01-24',
#      'currency_id': 'DKK',
#      'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#      'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#      'buying_sight': '4.6775000',
#      'buying_transfer': '4.6925000',
#      'selling': '4.7724000',
#      'mid_rate': '4.7325000'},
#     {'period': '2025-01-24',
#      'currency_id': 'NOK',
#      'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#      'currency_name_eng': 'NORWAY : KRONE (NOK)',
#      'buying_sight': '2.9605000',
#      'buying_transfer': '2.9724000',
#      'selling': '3.0377000',
#      'mid_rate': '3.0051000'},
#     {'period': '2025-01-24',
#      'currency_id': 'CNY',
#      'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#      'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#      'buying_sight': '4.5716000',
#      'buying_transfer': '4.5995000',
#      'selling': '4.7225000',
#      'mid_rate': '4.6610000'},
#     {'period': '2025-01-23',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '33.6759000',
#      'buying_transfer': '33.7636000',
#      'selling': '34.0863000',
#      'mid_rate': '33.9250000'},
#     {'period': '2025-01-23',
#      'currency_id': 'GBP',
#      'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#      'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#      'buying_sight': '41.2433000',
#      'buying_transfer': '41.3782000',
#      'selling': '42.1683000',
#      'mid_rate': '41.7733000'},
#     {'period': '2025-01-23',
#      'currency_id': 'EUR',
#      'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#      'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#      'buying_sight': '34.8514000',
#      'buying_transfer': '34.9548000',
#      'selling': '35.6231000',
#      'mid_rate': '35.2890000'},
#     {'period': '2025-01-23',
#      'currency_id': 'JPY',
#      'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#      'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#      'buying_sight': '21.2994000',
#      'buying_transfer': '21.3886000',
#      'selling': '22.0225000',
#      'mid_rate': '21.7056000'},
#     {'period': '2025-01-23',
#      'currency_id': 'HKD',
#      'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#      'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#      'buying_sight': '4.3016000',
#      'buying_transfer': '4.3177000',
#      'selling': '4.3957000',
#      'mid_rate': '4.3567000'},
#     {'period': '2025-01-23',
#      'currency_id': 'MYR',
#      'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#      'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#      'buying_sight': '7.4942000',
#      'buying_transfer': '7.5356000',
#      'selling': '7.7482000',
#      'mid_rate': '7.6419000'},
#     {'period': '2025-01-23',
#      'currency_id': 'SGD',
#      'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#      'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#      'buying_sight': '24.6849000',
#      'buying_transfer': '24.7538000',
#      'selling': '25.2993000',
#      'mid_rate': '25.0266000'},
#     {'period': '2025-01-23',
#      'currency_id': 'BND',
#      'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#      'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#      'buying_sight': '24.5774000',
#      'buying_transfer': '24.6674000',
#      'selling': '25.4237000',
#      'mid_rate': '25.0456000'},
#     {'period': '2025-01-23',
#      'currency_id': 'PHP',
#      'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#      'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#      'buying_sight': '0.5488000',
#      'buying_transfer': '0.5538000',
#      'selling': '0.6005000',
#      'mid_rate': '0.5772000'},
#     {'period': '2025-01-23',
#      'currency_id': 'IDR',
#      'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#      'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#      'buying_sight': '1.8940000',
#      'buying_transfer': '1.9893000',
#      'selling': '2.1936000',
#      'mid_rate': '2.0915000'},
#     {'period': '2025-01-23',
#      'currency_id': 'INR',
#      'currency_name_th': 'อินเดีย : รูปี (INR) ',
#      'currency_name_eng': 'INDIA : RUPEE (INR)',
#      'buying_sight': '0.3611000',
#      'buying_transfer': '0.3668000',
#      'selling': '0.4223000',
#      'mid_rate': '0.3946000'},
#     {'period': '2025-01-23',
#      'currency_id': 'CHF',
#      'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#      'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#      'buying_sight': '37.0201000',
#      'buying_transfer': '37.1124000',
#      'selling': '37.7404000',
#      'mid_rate': '37.4264000'},
#     {'period': '2025-01-23',
#      'currency_id': 'AUD',
#      'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#      'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#      'buying_sight': '20.7895000',
#      'buying_transfer': '20.8560000',
#      'selling': '21.6139000',
#      'mid_rate': '21.2350000'},
#     {'period': '2025-01-23',
#      'currency_id': 'NZD',
#      'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#      'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#      'buying_sight': '18.8367000',
#      'buying_transfer': '18.9040000',
#      'selling': '19.4930000',
#      'mid_rate': '19.1985000'},
#     {'period': '2025-01-23',
#      'currency_id': 'CAD',
#      'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#      'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#      'buying_sight': '23.2819000',
#      'buying_transfer': '23.3511000',
#      'selling': '23.8232000',
#      'mid_rate': '23.5872000'},
#     {'period': '2025-01-23',
#      'currency_id': 'SEK',
#      'currency_name_th': 'สวีเดน : โครนา (SEK)',
#      'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#      'buying_sight': '3.0345000',
#      'buying_transfer': '3.0492000',
#      'selling': '3.1118000',
#      'mid_rate': '3.0805000'},
#     {'period': '2025-01-23',
#      'currency_id': 'DKK',
#      'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#      'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#      'buying_sight': '4.6756000',
#      'buying_transfer': '4.6905000',
#      'selling': '4.7731000',
#      'mid_rate': '4.7318000'},
#     {'period': '2025-01-23',
#      'currency_id': 'NOK',
#      'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#      'currency_name_eng': 'NORWAY : KRONE (NOK)',
#      'buying_sight': '2.9545000',
#      'buying_transfer': '2.9666000',
#      'selling': '3.0343000',
#      'mid_rate': '3.0005000'},
#     {'period': '2025-01-23',
#      'currency_id': 'CNY',
#      'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#      'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#      'buying_sight': '4.5738000',
#      'buying_transfer': '4.6013000',
#      'selling': '4.7205000',
#      'mid_rate': '4.6609000'},
#     {'period': '2025-01-22',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '33.7300000',
#      'buying_transfer': '33.7934000',
#      'selling': '34.1071000',
#      'mid_rate': '33.9503000'},
#     {'period': '2025-01-22',
#      'currency_id': 'GBP',
#      'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#      'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#      'buying_sight': '41.2209000',
#      'buying_transfer': '41.3279000',
#      'selling': '42.0944000',
#      'mid_rate': '41.7112000'},
#     {'period': '2025-01-22',
#      'currency_id': 'EUR',
#      'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#      'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#      'buying_sight': '34.8396000',
#      'buying_transfer': '34.9215000',
#      'selling': '35.5579000',
#      'mid_rate': '35.2397000'},
#     {'period': '2025-01-22',
#      'currency_id': 'JPY',
#      'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#      'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#      'buying_sight': '21.4352000',
#      'buying_transfer': '21.5047000',
#      'selling': '22.1071000',
#      'mid_rate': '21.8059000'},
#     {'period': '2025-01-22',
#      'currency_id': 'HKD',
#      'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#      'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#      'buying_sight': '4.3195000',
#      'buying_transfer': '4.3337000',
#      'selling': '4.3901000',
#      'mid_rate': '4.3619000'},
#     {'period': '2025-01-22',
#      'currency_id': 'MYR',
#      'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#      'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#      'buying_sight': '7.4681000',
#      'buying_transfer': '7.5115000',
#      'selling': '7.7245000',
#      'mid_rate': '7.6180000'},
#     {'period': '2025-01-22',
#      'currency_id': 'SGD',
#      'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#      'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#      'buying_sight': '24.7032000',
#      'buying_transfer': '24.7632000',
#      'selling': '25.2771000',
#      'mid_rate': '25.0202000'},
#     {'period': '2025-01-22',
#      'currency_id': 'BND',
#      'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#      'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#      'buying_sight': '24.5626000',
#      'buying_transfer': '24.6526000',
#      'selling': '25.4043000',
#      'mid_rate': '25.0285000'},
#     {'period': '2025-01-22',
#      'currency_id': 'PHP',
#      'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#      'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#      'buying_sight': '0.5494000',
#      'buying_transfer': '0.5572000',
#      'selling': '0.5969000',
#      'mid_rate': '0.5771000'},
#     {'period': '2025-01-22',
#      'currency_id': 'IDR',
#      'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#      'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#      'buying_sight': '1.8932000',
#      'buying_transfer': '1.9790000',
#      'selling': '2.1867000',
#      'mid_rate': '2.0829000'},
#     {'period': '2025-01-22',
#      'currency_id': 'INR',
#      'currency_name_th': 'อินเดีย : รูปี (INR) ',
#      'currency_name_eng': 'INDIA : RUPEE (INR)',
#      'buying_sight': '0.3641000',
#      'buying_transfer': '0.3658000',
#      'selling': '0.4185000',
#      'mid_rate': '0.3922000'},
#     {'period': '2025-01-22',
#      'currency_id': 'CHF',
#      'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#      'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#      'buying_sight': '37.0375000',
#      'buying_transfer': '37.1071000',
#      'selling': '37.7244000',
#      'mid_rate': '37.4158000'},
#     {'period': '2025-01-22',
#      'currency_id': 'AUD',
#      'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#      'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#      'buying_sight': '20.7935000',
#      'buying_transfer': '20.8408000',
#      'selling': '21.5702000',
#      'mid_rate': '21.2055000'},
#     {'period': '2025-01-22',
#      'currency_id': 'NZD',
#      'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#      'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#      'buying_sight': '18.8173000',
#      'buying_transfer': '18.8780000',
#      'selling': '19.4368000',
#      'mid_rate': '19.1574000'},
#     {'period': '2025-01-22',
#      'currency_id': 'CAD',
#      'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#      'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#      'buying_sight': '23.3214000',
#      'buying_transfer': '23.3739000',
#      'selling': '23.8289000',
#      'mid_rate': '23.6014000'},
#     {'period': '2025-01-22',
#      'currency_id': 'SEK',
#      'currency_name_th': 'สวีเดน : โครนา (SEK)',
#      'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#      'buying_sight': '3.0303000',
#      'buying_transfer': '3.0428000',
#      'selling': '3.0930000',
#      'mid_rate': '3.0679000'},
#     {'period': '2025-01-22',
#      'currency_id': 'DKK',
#      'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#      'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#      'buying_sight': '4.6780000',
#      'buying_transfer': '4.6901000',
#      'selling': '4.7495000',
#      'mid_rate': '4.7198000'},
#     {'period': '2025-01-22',
#      'currency_id': 'NOK',
#      'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#      'currency_name_eng': 'NORWAY : KRONE (NOK)',
#      'buying_sight': '2.9462000',
#      'buying_transfer': '2.9571000',
#      'selling': '3.0104000',
#      'mid_rate': '2.9838000'},
#     {'period': '2025-01-22',
#      'currency_id': 'CNY',
#      'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#      'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#      'buying_sight': '4.6158000',
#      'buying_transfer': '4.6298000',
#      'selling': '4.7143000',
#      'mid_rate': '4.6721000'},
#     {'period': '2025-01-21',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '33.9285000',
#      'buying_transfer': '33.9911000',
#      'selling': '34.2975000',
#      'mid_rate': '34.1443000'},
#     {'period': '2025-01-21',
#      'currency_id': 'GBP',
#      'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#      'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#      'buying_sight': '41.3193000',
#      'buying_transfer': '41.4101000',
#      'selling': '42.1989000',
#      'mid_rate': '41.8045000'},
#     {'period': '2025-01-21',
#      'currency_id': 'EUR',
#      'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#      'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#      'buying_sight': '34.9163000',
#      'buying_transfer': '34.9998000',
#      'selling': '35.6684000',
#      'mid_rate': '35.3341000'},
#     {'period': '2025-01-21',
#      'currency_id': 'JPY',
#      'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#      'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#      'buying_sight': '21.5502000',
#      'buying_transfer': '21.6320000',
#      'selling': '22.2668000',
#      'mid_rate': '21.9494000'},
#     {'period': '2025-01-21',
#      'currency_id': 'HKD',
#      'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#      'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#      'buying_sight': '4.3473000',
#      'buying_transfer': '4.3618000',
#      'selling': '4.4217000',
#      'mid_rate': '4.3918000'},
#     {'period': '2025-01-21',
#      'currency_id': 'MYR',
# ...
#      'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#      'buying_sight': '21.5220000',
#      'buying_transfer': '21.6166000',
#      'selling': '22.2635000',
#      'mid_rate': '21.9401000'},
#     {'period': '2025-01-06',
#      'currency_id': 'HKD',
#      'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#      'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#      'buying_sight': '4.3945000',
#      'buying_transfer': '4.4099000',
#      'selling': '4.4852000',
#      'mid_rate': '4.4476000'},
#     {'period': '2025-01-06',
#      'currency_id': 'MYR',
#      'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#      'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#      'buying_sight': '7.5264000',
#      'buying_transfer': '7.5670000',
#      'selling': '7.7891000',
#      'mid_rate': '7.6781000'},
#     {'period': '2025-01-06',
#      'currency_id': 'SGD',
#      'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#      'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#      'buying_sight': '24.9132000',
#      'buying_transfer': '24.9830000',
#      'selling': '25.5318000',
#      'mid_rate': '25.2574000'},
#     {'period': '2025-01-06',
#      'currency_id': 'BND',
#      'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#      'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#      'buying_sight': '24.8256000',
#      'buying_transfer': '24.9156000',
#      'selling': '25.6648000',
#      'mid_rate': '25.2902000'},
#     {'period': '2025-01-06',
#      'currency_id': 'PHP',
#      'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#      'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#      'buying_sight': '0.5627000',
#      'buying_transfer': '0.5686000',
#      'selling': '0.6140000',
#      'mid_rate': '0.5913000'},
#     {'period': '2025-01-06',
#      'currency_id': 'IDR',
#      'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#      'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#      'buying_sight': '1.9609000',
#      'buying_transfer': '2.0488000',
#      'selling': '2.2446000',
#      'mid_rate': '2.1467000'},
#     {'period': '2025-01-06',
#      'currency_id': 'INR',
#      'currency_name_th': 'อินเดีย : รูปี (INR) ',
#      'currency_name_eng': 'INDIA : RUPEE (INR)',
#      'buying_sight': '0.3706000',
#      'buying_transfer': '0.3765000',
#      'selling': '0.4339000',
#      'mid_rate': '0.4052000'},
#     {'period': '2025-01-06',
#      'currency_id': 'CHF',
#      'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#      'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#      'buying_sight': '37.6310000',
#      'buying_transfer': '37.7081000',
#      'selling': '38.3829000',
#      'mid_rate': '38.0455000'},
#     {'period': '2025-01-06',
#      'currency_id': 'AUD',
#      'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#      'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#      'buying_sight': '21.0850000',
#      'buying_transfer': '21.1465000',
#      'selling': '21.9362000',
#      'mid_rate': '21.5414000'},
#     {'period': '2025-01-06',
#      'currency_id': 'NZD',
#      'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#      'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#      'buying_sight': '19.0904000',
#      'buying_transfer': '19.1523000',
#      'selling': '19.7544000',
#      'mid_rate': '19.4534000'},
#     {'period': '2025-01-06',
#      'currency_id': 'CAD',
#      'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#      'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#      'buying_sight': '23.6805000',
#      'buying_transfer': '23.7458000',
#      'selling': '24.2647000',
#      'mid_rate': '24.0053000'},
#     {'period': '2025-01-06',
#      'currency_id': 'SEK',
#      'currency_name_th': 'สวีเดน : โครนา (SEK)',
#      'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#      'buying_sight': '3.0718000',
#      'buying_transfer': '3.0861000',
#      'selling': '3.1448000',
#      'mid_rate': '3.1155000'},
#     {'period': '2025-01-06',
#      'currency_id': 'DKK',
#      'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#      'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#      'buying_sight': '4.7312000',
#      'buying_transfer': '4.7452000',
#      'selling': '4.8235000',
#      'mid_rate': '4.7844000'},
#     {'period': '2025-01-06',
#      'currency_id': 'NOK',
#      'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#      'currency_name_eng': 'NORWAY : KRONE (NOK)',
#      'buying_sight': '3.0009000',
#      'buying_transfer': '3.0131000',
#      'selling': '3.0757000',
#      'mid_rate': '3.0444000'},
#     {'period': '2025-01-06',
#      'currency_id': 'CNY',
#      'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#      'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#      'buying_sight': '4.6250000',
#      'buying_transfer': '4.6510000',
#      'selling': '4.7695000',
#      'mid_rate': '4.7103000'},
#     {'period': '2025-01-03',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '34.1695000',
#      'buying_transfer': '34.2643000',
#      'selling': '34.5899000',
#      'mid_rate': '34.4271000'},
#     {'period': '2025-01-03',
#      'currency_id': 'GBP',
#      'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#      'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#      'buying_sight': '42.0920000',
#      'buying_transfer': '42.2366000',
#      'selling': '43.0656000',
#      'mid_rate': '42.6511000'},
#     {'period': '2025-01-03',
#      'currency_id': 'EUR',
#      'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#      'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#      'buying_sight': '34.8843000',
#      'buying_transfer': '34.9936000',
#      'selling': '35.6972000',
#      'mid_rate': '35.3454000'},
#     {'period': '2025-01-03',
#      'currency_id': 'JPY',
#      'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#      'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#      'buying_sight': '21.4522000',
#      'buying_transfer': '21.5567000',
#      'selling': '22.2343000',
#      'mid_rate': '21.8955000'},
#     {'period': '2025-01-03',
#      'currency_id': 'HKD',
#      'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#      'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#      'buying_sight': '4.3676000',
#      'buying_transfer': '4.3845000',
#      'selling': '4.4679000',
#      'mid_rate': '4.4262000'},
#     {'period': '2025-01-03',
#      'currency_id': 'MYR',
#      'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#      'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#      'buying_sight': '7.5193000',
#      'buying_transfer': '7.5577000',
#      'selling': '7.7752000',
#      'mid_rate': '7.6665000'},
#     {'period': '2025-01-03',
#      'currency_id': 'SGD',
#      'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#      'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#      'buying_sight': '24.7931000',
#      'buying_transfer': '24.8674000',
#      'selling': '25.4403000',
#      'mid_rate': '25.1539000'},
#     {'period': '2025-01-03',
#      'currency_id': 'BND',
#      'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#      'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#      'buying_sight': '24.6988000',
#      'buying_transfer': '24.7888000',
#      'selling': '25.5419000',
#      'mid_rate': '25.1654000'},
#     {'period': '2025-01-03',
#      'currency_id': 'PHP',
#      'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#      'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#      'buying_sight': '0.5613000',
#      'buying_transfer': '0.5673000',
#      'selling': '0.6140000',
#      'mid_rate': '0.5907000'},
#     {'period': '2025-01-03',
#      'currency_id': 'IDR',
#      'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#      'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#      'buying_sight': '1.9544000',
#      'buying_transfer': '2.0400000',
#      'selling': '2.2280000',
#      'mid_rate': '2.1340000'},
#     {'period': '2025-01-03',
#      'currency_id': 'INR',
#      'currency_name_th': 'อินเดีย : รูปี (INR) ',
#      'currency_name_eng': 'INDIA : RUPEE (INR)',
#      'buying_sight': '0.3731000',
#      'buying_transfer': '0.3766000',
#      'selling': '0.4356000',
#      'mid_rate': '0.4061000'},
#     {'period': '2025-01-03',
#      'currency_id': 'CHF',
#      'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#      'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#      'buying_sight': '37.3168000',
#      'buying_transfer': '37.4103000',
#      'selling': '38.1130000',
#      'mid_rate': '37.7617000'},
#     {'period': '2025-01-03',
#      'currency_id': 'AUD',
#      'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#      'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#      'buying_sight': '20.8888000',
#      'buying_transfer': '20.9585000',
#      'selling': '21.7799000',
#      'mid_rate': '21.3692000'},
#     {'period': '2025-01-03',
#      'currency_id': 'NZD',
#      'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#      'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#      'buying_sight': '18.9077000',
#      'buying_transfer': '18.9789000',
#      'selling': '19.5988000',
#      'mid_rate': '19.2889000'},
#     {'period': '2025-01-03',
#      'currency_id': 'CAD',
#      'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#      'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#      'buying_sight': '23.5547000',
#      'buying_transfer': '23.6320000',
#      'selling': '24.1706000',
#      'mid_rate': '23.9013000'},
#     {'period': '2025-01-03',
#      'currency_id': 'SEK',
#      'currency_name_th': 'สวีเดน : โครนา (SEK)',
#      'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#      'buying_sight': '3.0397000',
#      'buying_transfer': '3.0551000',
#      'selling': '3.1216000',
#      'mid_rate': '3.0884000'},
#     {'period': '2025-01-03',
#      'currency_id': 'DKK',
#      'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#      'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#      'buying_sight': '4.6785000',
#      'buying_transfer': '4.6944000',
#      'selling': '4.7858000',
#      'mid_rate': '4.7401000'},
#     {'period': '2025-01-03',
#      'currency_id': 'NOK',
#      'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#      'currency_name_eng': 'NORWAY : KRONE (NOK)',
#      'buying_sight': '2.9726000',
#      'buying_transfer': '2.9854000',
#      'selling': '3.0577000',
#      'mid_rate': '3.0216000'},
#     {'period': '2025-01-03',
#      'currency_id': 'CNY',
#      'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#      'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#      'buying_sight': '4.6052000',
#      'buying_transfer': '4.6372000',
#      'selling': '4.7713000',
#      'mid_rate': '4.7043000'},
#     {'period': '2025-01-02',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '33.9631000',
#      'buying_transfer': '34.0420000',
#      'selling': '34.3667000',
#      'mid_rate': '34.2044000'},
#     {'period': '2025-01-02',
#      'currency_id': 'GBP',
#      'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#      'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#      'buying_sight': '42.3259000',
#      'buying_transfer': '42.4359000',
#      'selling': '43.2382000',
#      'mid_rate': '42.8371000'},
#     {'period': '2025-01-02',
#      'currency_id': 'EUR',
#      'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#      'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#      'buying_sight': '35.0109000',
#      'buying_transfer': '35.0865000',
#      'selling': '35.7634000',
#      'mid_rate': '35.4250000'},
#     {'period': '2025-01-02',
#      'currency_id': 'JPY',
#      'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#      'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#      'buying_sight': '21.3616000',
#      'buying_transfer': '21.4332000',
#      'selling': '22.0794000',
#      'mid_rate': '21.7563000'},
#     {'period': '2025-01-02',
#      'currency_id': 'HKD',
#      'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#      'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#      'buying_sight': '4.3498000',
#      'buying_transfer': '4.3651000',
#      'selling': '4.4349000',
#      'mid_rate': '4.4000000'},
#     {'period': '2025-01-02',
#      'currency_id': 'MYR',
#      'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#      'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#      'buying_sight': '7.4907000',
#      'buying_transfer': '7.5304000',
#      'selling': '7.7525000',
#      'mid_rate': '7.6415000'},
#     {'period': '2025-01-02',
#      'currency_id': 'SGD',
#      'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#      'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#      'buying_sight': '24.7696000',
#      'buying_transfer': '24.8323000',
#      'selling': '25.3767000',
#      'mid_rate': '25.1045000'},
#     {'period': '2025-01-02',
#      'currency_id': 'BND',
#      'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#      'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#      'buying_sight': '24.6391000',
#      'buying_transfer': '24.7291000',
#      'selling': '25.4706000',
#      'mid_rate': '25.0999000'},
#     {'period': '2025-01-02',
#      'currency_id': 'PHP',
#      'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#      'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#      'buying_sight': '0.5600000',
#      'buying_transfer': '0.5667000',
#      'selling': '0.6117000',
#      'mid_rate': '0.5892000'},
#     {'period': '2025-01-02',
#      'currency_id': 'IDR',
#      'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#      'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#      'buying_sight': '1.9459000',
#      'buying_transfer': '2.0309000',
#      'selling': '2.2243000',
#      'mid_rate': '2.1276000'},
#     {'period': '2025-01-02',
#      'currency_id': 'INR',
#      'currency_name_th': 'อินเดีย : รูปี (INR) ',
#      'currency_name_eng': 'INDIA : RUPEE (INR)',
#      'buying_sight': '0.3717000',
#      'buying_transfer': '0.3782000',
#      'selling': '0.4339000',
#      'mid_rate': '0.4061000'},
#     {'period': '2025-01-02',
#      'currency_id': 'CHF',
#      'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#      'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#      'buying_sight': '37.3788000',
#      'buying_transfer': '37.4404000',
#      'selling': '38.1119000',
#      'mid_rate': '37.7762000'},
#     {'period': '2025-01-02',
#      'currency_id': 'AUD',
#      'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#      'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#      'buying_sight': '20.8074000',
#      'buying_transfer': '20.8432000',
#      'selling': '21.6385000',
#      'mid_rate': '21.2409000'},
#     {'period': '2025-01-02',
#      'currency_id': 'NZD',
#      'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#      'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#      'buying_sight': '18.8425000',
#      'buying_transfer': '18.9054000',
#      'selling': '19.4933000',
#      'mid_rate': '19.1994000'},
#     {'period': '2025-01-02',
#      'currency_id': 'CAD',
#      'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#      'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#      'buying_sight': '23.4831000',
#      'buying_transfer': '23.5332000',
#      'selling': '24.0778000',
#      'mid_rate': '23.8055000'},
#     {'period': '2025-01-02',
#      'currency_id': 'SEK',
#      'currency_name_th': 'สวีเดน : โครนา (SEK)',
#      'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#      'buying_sight': '3.0510000',
#      'buying_transfer': '3.0645000',
#      'selling': '3.1210000',
#      'mid_rate': '3.0928000'},
#     {'period': '2025-01-02',
#      'currency_id': 'DKK',
#      'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#      'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#      'buying_sight': '4.7038000',
#      'buying_transfer': '4.7173000',
#      'selling': '4.7892000',
#      'mid_rate': '4.7533000'},
#     {'period': '2025-01-02',
#      'currency_id': 'NOK',
#      'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#      'currency_name_eng': 'NORWAY : KRONE (NOK)',
#      'buying_sight': '2.9661000',
#      'buying_transfer': '2.9779000',
#      'selling': '3.0379000',
#      'mid_rate': '3.0079000'},
#     {'period': '2025-01-02',
#      'currency_id': 'CNY',
#      'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#      'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#      'buying_sight': '4.6004000',
#      'buying_transfer': '4.6225000',
#      'selling': '4.7306000',
#      'mid_rate': '4.6766000'}]}}}

# %%
data['result']['data']['data_detail']
# Out:
# [{'period': '2025-01-31',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '33.4092000',
#   'buying_transfer': '33.4853000',
#   'selling': '33.8042000',
#   'mid_rate': '33.6448000'},
#  {'period': '2025-01-31',
#   'currency_id': 'GBP',
#   'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#   'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#   'buying_sight': '41.3458000',
#   'buying_transfer': '41.4482000',
#   'selling': '42.2217000',
#   'mid_rate': '41.8350000'},
#  {'period': '2025-01-31',
#   'currency_id': 'EUR',
#   'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#   'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#   'buying_sight': '34.6041000',
#   'buying_transfer': '34.6845000',
#   'selling': '35.3091000',
#   'mid_rate': '34.9968000'},
#  {'period': '2025-01-31',
#   'currency_id': 'JPY',
#   'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#   'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#   'buying_sight': '21.4119000',
#   'buying_transfer': '21.4908000',
#   'selling': '22.0914000',
#   'mid_rate': '21.7911000'},
#  {'period': '2025-01-31',
#   'currency_id': 'HKD',
#   'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#   'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#   'buying_sight': '4.2719000',
#   'buying_transfer': '4.2866000',
#   'selling': '4.3520000',
#   'mid_rate': '4.3193000'},
#  {'period': '2025-01-31',
#   'currency_id': 'MYR',
#   'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#   'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#   'buying_sight': '7.4630000',
#   'buying_transfer': '7.5047000',
#   'selling': '7.7204000',
#   'mid_rate': '7.6126000'},
#  {'period': '2025-01-31',
#   'currency_id': 'SGD',
#   'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#   'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#   'buying_sight': '24.5665000',
#   'buying_transfer': '24.6276000',
#   'selling': '25.1421000',
#   'mid_rate': '24.8849000'},
#  {'period': '2025-01-31',
#   'currency_id': 'BND',
#   'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#   'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#   'buying_sight': '24.3800000',
#   'buying_transfer': '24.4700000',
#   'selling': '25.2239000',
#   'mid_rate': '24.8470000'},
#  {'period': '2025-01-31',
#   'currency_id': 'PHP',
#   'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#   'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#   'buying_sight': '0.5466000',
#   'buying_transfer': '0.5524000',
#   'selling': '0.5955000',
#   'mid_rate': '0.5740000'},
#  {'period': '2025-01-31',
#   'currency_id': 'IDR',
#   'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#   'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#   'buying_sight': '1.8879000',
#   'buying_transfer': '1.9773000',
#   'selling': '2.1709000',
#   'mid_rate': '2.0741000'},
#  {'period': '2025-01-31',
#   'currency_id': 'INR',
#   'currency_name_th': 'อินเดีย : รูปี (INR) ',
#   'currency_name_eng': 'INDIA : RUPEE (INR)',
#   'buying_sight': '0.3614000',
#   'buying_transfer': '0.3620000',
#   'selling': '0.4200000',
#   'mid_rate': '0.3910000'},
#  {'period': '2025-01-31',
#   'currency_id': 'CHF',
#   'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#   'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#   'buying_sight': '36.6829000',
#   'buying_transfer': '36.7324000',
#   'selling': '37.3130000',
#   'mid_rate': '37.0227000'},
#  {'period': '2025-01-31',
#   'currency_id': 'AUD',
#   'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#   'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#   'buying_sight': '20.5368000',
#   'buying_transfer': '20.5718000',
#   'selling': '21.3222000',
#   'mid_rate': '20.9470000'},
#  {'period': '2025-01-31',
#   'currency_id': 'NZD',
#   'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#   'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#   'buying_sight': '18.6671000',
#   'buying_transfer': '18.7272000',
#   'selling': '19.3043000',
#   'mid_rate': '19.0158000'},
#  {'period': '2025-01-31',
#   'currency_id': 'CAD',
#   'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#   'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#   'buying_sight': '23.0194000',
#   'buying_transfer': '23.0748000',
#   'selling': '23.4955000',
#   'mid_rate': '23.2852000'},
#  {'period': '2025-01-31',
#   'currency_id': 'SEK',
#   'currency_name_th': 'สวีเดน : โครนา (SEK)',
#   'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#   'buying_sight': '3.0139000',
#   'buying_transfer': '3.0262000',
#   'selling': '3.0792000',
#   'mid_rate': '3.0527000'},
#  {'period': '2025-01-31',
#   'currency_id': 'DKK',
#   'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#   'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#   'buying_sight': '4.6479000',
#   'buying_transfer': '4.6604000',
#   'selling': '4.7260000',
#   'mid_rate': '4.6932000'},
#  {'period': '2025-01-31',
#   'currency_id': 'NOK',
#   'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#   'currency_name_eng': 'NORWAY : KRONE (NOK)',
#   'buying_sight': '2.9365000',
#   'buying_transfer': '2.9477000',
#   'selling': '3.0045000',
#   'mid_rate': '2.9761000'},
#  {'period': '2025-01-31',
#   'currency_id': 'CNY',
#   'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#   'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#   'buying_sight': '4.5543000',
#   'buying_transfer': '4.5736000',
#   'selling': '4.6716000',
#   'mid_rate': '4.6226000'},
#  {'period': '2025-01-30',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '33.5611000',
#   'buying_transfer': '33.6210000',
#   'selling': '33.9338000',
#   'mid_rate': '33.7774000'},
#  {'period': '2025-01-30',
#   'currency_id': 'GBP',
#   'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#   'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#   'buying_sight': '41.5432000',
#   'buying_transfer': '41.6436000',
#   'selling': '42.4391000',
#   'mid_rate': '42.0414000'},
#  {'period': '2025-01-30',
#   'currency_id': 'EUR',
#   'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#   'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#   'buying_sight': '34.8185000',
#   'buying_transfer': '34.8915000',
#   'selling': '35.5482000',
#   'mid_rate': '35.2199000'},
#  {'period': '2025-01-30',
#   'currency_id': 'JPY',
#   'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#   'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#   'buying_sight': '21.4332000',
#   'buying_transfer': '21.4999000',
#   'selling': '22.1343000',
#   'mid_rate': '21.8171000'},
#  {'period': '2025-01-30',
#   'currency_id': 'HKD',
#   'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#   'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#   'buying_sight': '4.2972000',
#   'buying_transfer': '4.3106000',
#   'selling': '4.3622000',
#   'mid_rate': '4.3364000'},
#  {'period': '2025-01-30',
#   'currency_id': 'MYR',
#   'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#   'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#   'buying_sight': '7.5576000',
#   'buying_transfer': '7.5806000',
#   'selling': '7.8010000',
#   'mid_rate': '7.6908000'},
#  {'period': '2025-01-30',
#   'currency_id': 'SGD',
#   'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#   'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#   'buying_sight': '24.7004000',
#   'buying_transfer': '24.7459000',
#   'selling': '25.2820000',
#   'mid_rate': '25.0140000'},
#  {'period': '2025-01-30',
#   'currency_id': 'BND',
#   'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#   'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#   'buying_sight': '24.5547000',
#   'buying_transfer': '24.6447000',
#   'selling': '25.4053000',
#   'mid_rate': '25.0250000'},
#  {'period': '2025-01-30',
#   'currency_id': 'PHP',
#   'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#   'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#   'buying_sight': '0.5485000',
#   'buying_transfer': '0.5537000',
#   'selling': '0.5993000',
#   'mid_rate': '0.5765000'},
#  {'period': '2025-01-30',
#   'currency_id': 'IDR',
#   'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#   'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#   'buying_sight': '1.8749000',
#   'buying_transfer': '1.9795000',
#   'selling': '2.1978000',
#   'mid_rate': '2.0887000'},
#  {'period': '2025-01-30',
#   'currency_id': 'INR',
#   'currency_name_th': 'อินเดีย : รูปี (INR) ',
#   'currency_name_eng': 'INDIA : RUPEE (INR)',
#   'buying_sight': '0.3642000',
#   'buying_transfer': '0.3645000',
#   'selling': '0.4204000',
#   'mid_rate': '0.3925000'},
#  {'period': '2025-01-30',
#   'currency_id': 'CHF',
#   'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#   'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#   'buying_sight': '36.9202000',
#   'buying_transfer': '36.9898000',
#   'selling': '37.5996000',
#   'mid_rate': '37.2947000'},
#  {'period': '2025-01-30',
#   'currency_id': 'AUD',
#   'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#   'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#   'buying_sight': '20.6332000',
#   'buying_transfer': '20.6795000',
#   'selling': '21.4587000',
#   'mid_rate': '21.0691000'},
#  {'period': '2025-01-30',
#   'currency_id': 'NZD',
#   'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#   'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#   'buying_sight': '18.7837000',
#   'buying_transfer': '18.8287000',
#   'selling': '19.4195000',
#   'mid_rate': '19.1241000'},
#  {'period': '2025-01-30',
#   'currency_id': 'CAD',
#   'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#   'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#   'buying_sight': '23.2001000',
#   'buying_transfer': '23.2569000',
#   'selling': '23.7069000',
#   'mid_rate': '23.4819000'},
#  {'period': '2025-01-30',
#   'currency_id': 'SEK',
#   'currency_name_th': 'สวีเดน : โครนา (SEK)',
#   'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#   'buying_sight': '3.0368000',
#   'buying_transfer': '3.0484000',
#   'selling': '3.0960000',
#   'mid_rate': '3.0722000'},
#  {'period': '2025-01-30',
#   'currency_id': 'DKK',
#   'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#   'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#   'buying_sight': '4.6828000',
#   'buying_transfer': '4.6943000',
#   'selling': '4.7503000',
#   'mid_rate': '4.7223000'},
#  {'period': '2025-01-30',
#   'currency_id': 'NOK',
#   'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#   'currency_name_eng': 'NORWAY : KRONE (NOK)',
#   'buying_sight': '2.9541000',
#   'buying_transfer': '2.9646000',
#   'selling': '3.0148000',
#   'mid_rate': '2.9897000'},
#  {'period': '2025-01-30',
#   'currency_id': 'CNY',
#   'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#   'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#   'buying_sight': '4.6005000',
#   'buying_transfer': '4.6081000',
#   'selling': '4.6962000',
#   'mid_rate': '4.6522000'},
#  {'period': '2025-01-29',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '33.5344000',
#   'buying_transfer': '33.6150000',
#   'selling': '33.9397000',
#   'mid_rate': '33.7774000'},
#  {'period': '2025-01-29',
#   'currency_id': 'GBP',
#   'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#   'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#   'buying_sight': '41.5119000',
#   'buying_transfer': '41.6327000',
#   'selling': '42.4517000',
#   'mid_rate': '42.0422000'},
#  {'period': '2025-01-29',
#   'currency_id': 'EUR',
#   'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#   'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#   'buying_sight': '34.7989000',
#   'buying_transfer': '34.8899000',
#   'selling': '35.5745000',
#   'mid_rate': '35.2322000'},
#  {'period': '2025-01-29',
#   'currency_id': 'JPY',
#   'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#   'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#   'buying_sight': '21.3209000',
#   'buying_transfer': '21.4139000',
#   'selling': '22.0633000',
#   'mid_rate': '21.7386000'},
#  {'period': '2025-01-29',
#   'currency_id': 'HKD',
#   'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#   'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#   'buying_sight': '4.2845000',
#   'buying_transfer': '4.2992000',
#   'selling': '4.3762000',
#   'mid_rate': '4.3377000'},
#  {'period': '2025-01-29',
#   'currency_id': 'MYR',
#   'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#   'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#   'buying_sight': '7.5356000',
#   'buying_transfer': '7.5801000',
#   'selling': '7.8010000',
#   'mid_rate': '7.6906000'},
#  {'period': '2025-01-29',
#   'currency_id': 'SGD',
#   'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#   'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#   'buying_sight': '24.6658000',
#   'buying_transfer': '24.7323000',
#   'selling': '25.2934000',
#   'mid_rate': '25.0129000'},
#  {'period': '2025-01-29',
#   'currency_id': 'BND',
#   'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#   'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#   'buying_sight': '24.5279000',
#   'buying_transfer': '24.6179000',
#   'selling': '25.3759000',
#   'mid_rate': '24.9969000'},
#  {'period': '2025-01-29',
#   'currency_id': 'PHP',
#   'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#   'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#   'buying_sight': '0.5473000',
#   'buying_transfer': '0.5538000',
#   'selling': '0.5968000',
#   'mid_rate': '0.5753000'},
#  {'period': '2025-01-29',
#   'currency_id': 'IDR',
#   'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#   'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#   'buying_sight': '1.9117000',
#   'buying_transfer': '1.9938000',
#   'selling': '2.1966000',
#   'mid_rate': '2.0952000'},
#  {'period': '2025-01-29',
#   'currency_id': 'INR',
#   'currency_name_th': 'อินเดีย : รูปี (INR) ',
#   'currency_name_eng': 'INDIA : RUPEE (INR)',
#   'buying_sight': '0.3581000',
#   'buying_transfer': '0.3606000',
#   'selling': '0.4224000',
#   'mid_rate': '0.3915000'},
#  {'period': '2025-01-29',
#   'currency_id': 'CHF',
#   'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#   'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#   'buying_sight': '36.9664000',
#   'buying_transfer': '37.0546000',
#   'selling': '37.6813000',
#   'mid_rate': '37.3680000'},
#  {'period': '2025-01-29',
#   'currency_id': 'AUD',
#   'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#   'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#   'buying_sight': '20.6139000',
#   'buying_transfer': '20.6743000',
#   'selling': '21.4675000',
#   'mid_rate': '21.0709000'},
#  {'period': '2025-01-29',
#   'currency_id': 'NZD',
#   'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#   'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#   'buying_sight': '18.7560000',
#   'buying_transfer': '18.8195000',
#   'selling': '19.4411000',
#   'mid_rate': '19.1303000'},
#  {'period': '2025-01-29',
#   'currency_id': 'CAD',
#   'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#   'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#   'buying_sight': '23.1569000',
#   'buying_transfer': '23.2276000',
#   'selling': '23.7036000',
#   'mid_rate': '23.4656000'},
#  {'period': '2025-01-29',
#   'currency_id': 'SEK',
#   'currency_name_th': 'สวีเดน : โครนา (SEK)',
#   'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#   'buying_sight': '3.0263000',
#   'buying_transfer': '3.0420000',
#   'selling': '3.1041000',
#   'mid_rate': '3.0731000'},
#  {'period': '2025-01-29',
#   'currency_id': 'DKK',
#   'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#   'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#   'buying_sight': '4.6704000',
#   'buying_transfer': '4.6855000',
#   'selling': '4.7661000',
#   'mid_rate': '4.7258000'},
#  {'period': '2025-01-29',
#   'currency_id': 'NOK',
#   'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#   'currency_name_eng': 'NORWAY : KRONE (NOK)',
#   'buying_sight': '2.9455000',
#   'buying_transfer': '2.9581000',
#   'selling': '3.0256000',
#   'mid_rate': '2.9919000'},
#  {'period': '2025-01-29',
#   'currency_id': 'CNY',
#   'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#   'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#   'buying_sight': '4.5641000',
#   'buying_transfer': '4.5908000',
#   'selling': '4.7138000',
#   'mid_rate': '4.6523000'},
#  {'period': '2025-01-28',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '33.6251000',
#   'buying_transfer': '33.7090000',
#   'selling': '34.0311000',
#   'mid_rate': '33.8701000'},
#  {'period': '2025-01-28',
#   'currency_id': 'GBP',
#   'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#   'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#   'buying_sight': '41.6321000',
#   'buying_transfer': '41.7565000',
#   'selling': '42.5551000',
#   'mid_rate': '42.1558000'},
#  {'period': '2025-01-28',
#   'currency_id': 'EUR',
#   'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#   'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#   'buying_sight': '34.9540000',
#   'buying_transfer': '35.0327000',
#   'selling': '35.7140000',
#   'mid_rate': '35.3734000'},
#  {'period': '2025-01-28',
#   'currency_id': 'JPY',
#   'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#   'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#   'buying_sight': '21.3712000',
#   'buying_transfer': '21.4562000',
#   'selling': '22.0972000',
#   'mid_rate': '21.7767000'},
#  {'period': '2025-01-28',
#   'currency_id': 'HKD',
#   'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#   'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#   'buying_sight': '4.2970000',
#   'buying_transfer': '4.3133000',
#   'selling': '4.3860000',
#   'mid_rate': '4.3497000'},
#  {'period': '2025-01-28',
#   'currency_id': 'MYR',
#   'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#   'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#   'buying_sight': '7.5564000',
#   'buying_transfer': '7.5976000',
#   'selling': '7.8216000',
#   'mid_rate': '7.7096000'},
#  {'period': '2025-01-28',
#   'currency_id': 'SGD',
#   'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#   'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#   'buying_sight': '24.7499000',
#   'buying_transfer': '24.8118000',
#   'selling': '25.3668000',
#   'mid_rate': '25.0893000'},
#  {'period': '2025-01-28',
#   'currency_id': 'BND',
#   'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#   'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#   'buying_sight': '24.6093000',
#   'buying_transfer': '24.6993000',
#   'selling': '25.4558000',
#   'mid_rate': '25.0776000'},
#  {'period': '2025-01-28',
#   'currency_id': 'PHP',
#   'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#   'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#   'buying_sight': '0.5493000',
#   'buying_transfer': '0.5542000',
#   'selling': '0.6020000',
#   'mid_rate': '0.5781000'},
#  {'period': '2025-01-28',
#   'currency_id': 'IDR',
#   'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#   'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#   'buying_sight': '1.9368000',
#   'buying_transfer': '2.0102000',
#   'selling': '2.2006000',
#   'mid_rate': '2.1054000'},
#  {'period': '2025-01-28',
#   'currency_id': 'INR',
#   'currency_name_th': 'อินเดีย : รูปี (INR) ',
#   'currency_name_eng': 'INDIA : RUPEE (INR)',
#   'buying_sight': '0.3593000',
#   'buying_transfer': '0.3655000',
#   'selling': '0.4205000',
#   'mid_rate': '0.3930000'},
#  {'period': '2025-01-28',
#   'currency_id': 'CHF',
#   'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#   'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#   'buying_sight': '37.0225000',
#   'buying_transfer': '37.1031000',
#   'selling': '37.7528000',
#   'mid_rate': '37.4280000'},
#  {'period': '2025-01-28',
#   'currency_id': 'AUD',
#   'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#   'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#   'buying_sight': '20.7711000',
#   'buying_transfer': '20.8237000',
#   'selling': '21.6182000',
#   'mid_rate': '21.2210000'},
#  {'period': '2025-01-28',
#   'currency_id': 'NZD',
#   'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#   'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#   'buying_sight': '18.8435000',
#   'buying_transfer': '18.9059000',
#   'selling': '19.5224000',
#   'mid_rate': '19.2142000'},
#  {'period': '2025-01-28',
#   'currency_id': 'CAD',
#   'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#   'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#   'buying_sight': '23.2392000',
#   'buying_transfer': '23.2966000',
#   'selling': '23.7756000',
#   'mid_rate': '23.5361000'},
#  {'period': '2025-01-28',
#   'currency_id': 'SEK',
#   'currency_name_th': 'สวีเดน : โครนา (SEK)',
#   'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#   'buying_sight': '3.0400000',
#   'buying_transfer': '3.0548000',
#   'selling': '3.1132000',
#   'mid_rate': '3.0840000'},
#  {'period': '2025-01-28',
#   'currency_id': 'DKK',
#   'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#   'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#   'buying_sight': '4.6918000',
#   'buying_transfer': '4.7063000',
#   'selling': '4.7828000',
#   'mid_rate': '4.7446000'},
#  {'period': '2025-01-28',
#   'currency_id': 'NOK',
#   'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#   'currency_name_eng': 'NORWAY : KRONE (NOK)',
#   'buying_sight': '2.9595000',
#   'buying_transfer': '2.9714000',
#   'selling': '3.0340000',
#   'mid_rate': '3.0027000'},
#  {'period': '2025-01-28',
#   'currency_id': 'CNY',
#   'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#   'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#   'buying_sight': '4.5823000',
#   'buying_transfer': '4.6050000',
#   'selling': '4.7177000',
#   'mid_rate': '4.6614000'},
#  {'period': '2025-01-27',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '33.4561000',
#   'buying_transfer': '33.5507000',
#   'selling': '33.8757000',
#   'mid_rate': '33.7132000'},
#  {'period': '2025-01-27',
#   'currency_id': 'GBP',
#   'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#   'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#   'buying_sight': '41.4056000',
#   'buying_transfer': '41.5625000',
#   'selling': '42.3930000',
#   'mid_rate': '41.9778000'},
#  {'period': '2025-01-27',
#   'currency_id': 'EUR',
#   'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#   'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#   'buying_sight': '34.8020000',
#   'buying_transfer': '34.9063000',
#   'selling': '35.6201000',
#   'mid_rate': '35.2632000'},
#  {'period': '2025-01-27',
#   'currency_id': 'JPY',
#   'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#   'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#   'buying_sight': '21.2223000',
#   'buying_transfer': '21.3263000',
#   'selling': '22.0016000',
#   'mid_rate': '21.6640000'},
#  {'period': '2025-01-27',
#   'currency_id': 'HKD',
#   'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#   'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#   'buying_sight': '4.2689000',
#   'buying_transfer': '4.2849000',
#   'selling': '4.3726000',
#   'mid_rate': '4.3288000'},
#  {'period': '2025-01-27',
#   'currency_id': 'MYR',
#   'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#   'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#   'buying_sight': '7.5613000',
#   'buying_transfer': '7.6024000',
#   'selling': '7.8169000',
#   'mid_rate': '7.7097000'},
#  {'period': '2025-01-27',
#   'currency_id': 'SGD',
#   'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#   'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#   'buying_sight': '24.6480000',
#   'buying_transfer': '24.7180000',
#   'selling': '25.3059000',
#   'mid_rate': '25.0120000'},
#  {'period': '2025-01-27',
#   'currency_id': 'BND',
#   'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#   'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#   'buying_sight': '24.5611000',
#   'buying_transfer': '24.6511000',
#   'selling': '25.4081000',
#   'mid_rate': '25.0296000'},
#  {'period': '2025-01-27',
#   'currency_id': 'PHP',
#   'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#   'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#   'buying_sight': '0.5478000',
#   'buying_transfer': '0.5524000',
#   'selling': '0.5985000',
#   'mid_rate': '0.5755000'},
#  {'period': '2025-01-27',
#   'currency_id': 'IDR',
#   'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#   'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#   'buying_sight': '1.9085000',
#   'buying_transfer': '1.9944000',
#   'selling': '2.1902000',
#   'mid_rate': '2.0923000'},
#  {'period': '2025-01-27',
#   'currency_id': 'INR',
#   'currency_name_th': 'อินเดีย : รูปี (INR) ',
#   'currency_name_eng': 'INDIA : RUPEE (INR)',
#   'buying_sight': '0.3606000',
#   'buying_transfer': '0.3622000',
#   'selling': '0.4201000',
#   'mid_rate': '0.3912000'},
#  {'period': '2025-01-27',
#   'currency_id': 'CHF',
#   'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#   'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#   'buying_sight': '36.7505000',
#   'buying_transfer': '36.8586000',
#   'selling': '37.5172000',
#   'mid_rate': '37.1879000'},
#  {'period': '2025-01-27',
#   'currency_id': 'AUD',
#   'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#   'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#   'buying_sight': '20.6998000',
#   'buying_transfer': '20.7777000',
#   'selling': '21.6053000',
#   'mid_rate': '21.1915000'},
#  {'period': '2025-01-27',
#   'currency_id': 'NZD',
#   'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#   'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#   'buying_sight': '18.7836000',
#   'buying_transfer': '18.8464000',
#   'selling': '19.4959000',
#   'mid_rate': '19.1712000'},
#  {'period': '2025-01-27',
#   'currency_id': 'CAD',
#   'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#   'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#   'buying_sight': '23.1050000',
#   'buying_transfer': '23.1832000',
#   'selling': '23.6936000',
#   'mid_rate': '23.4384000'},
#  {'period': '2025-01-27',
#   'currency_id': 'SEK',
#   'currency_name_th': 'สวีเดน : โครนา (SEK)',
#   'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#   'buying_sight': '3.0206000',
#   'buying_transfer': '3.0382000',
#   'selling': '3.1089000',
#   'mid_rate': '3.0736000'},
#  {'period': '2025-01-27',
#   'currency_id': 'DKK',
#   'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#   'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#   'buying_sight': '4.6631000',
#   'buying_transfer': '4.6806000',
#   'selling': '4.7796000',
#   'mid_rate': '4.7301000'},
#  {'period': '2025-01-27',
#   'currency_id': 'NOK',
#   'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#   'currency_name_eng': 'NORWAY : KRONE (NOK)',
#   'buying_sight': '2.9449000',
#   'buying_transfer': '2.9585000',
#   'selling': '3.0351000',
#   'mid_rate': '2.9968000'},
#  {'period': '2025-01-27',
#   'currency_id': 'CNY',
#   'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#   'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#   'buying_sight': '4.5368000',
#   'buying_transfer': '4.5726000',
#   'selling': '4.7168000',
#   'mid_rate': '4.6447000'},
#  {'period': '2025-01-24',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '33.6055000',
#   'buying_transfer': '33.6866000',
#   'selling': '34.0252000',
#   'mid_rate': '33.8559000'},
#  {'period': '2025-01-24',
#   'currency_id': 'GBP',
#   'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#   'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#   'buying_sight': '41.3165000',
#   'buying_transfer': '41.4405000',
#   'selling': '42.2538000',
#   'mid_rate': '41.8472000'},
#  {'period': '2025-01-24',
#   'currency_id': 'EUR',
#   'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#   'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#   'buying_sight': '34.8594000',
#   'buying_transfer': '34.9532000',
#   'selling': '35.6373000',
#   'mid_rate': '35.2953000'},
#  {'period': '2025-01-24',
#   'currency_id': 'JPY',
#   'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#   'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#   'buying_sight': '21.3072000',
#   'buying_transfer': '21.4030000',
#   'selling': '22.0459000',
#   'mid_rate': '21.7245000'},
#  {'period': '2025-01-24',
#   'currency_id': 'HKD',
#   'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#   'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#   'buying_sight': '4.2953000',
#   'buying_transfer': '4.3101000',
#   'selling': '4.3866000',
#   'mid_rate': '4.3484000'},
#  {'period': '2025-01-24',
#   'currency_id': 'MYR',
#   'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#   'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#   'buying_sight': '7.5111000',
#   'buying_transfer': '7.5520000',
#   'selling': '7.7699000',
#   'mid_rate': '7.6610000'},
#  {'period': '2025-01-24',
#   'currency_id': 'SGD',
#   'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#   'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#   'buying_sight': '24.6821000',
#   'buying_transfer': '24.7499000',
#   'selling': '25.3106000',
#   'mid_rate': '25.0303000'},
#  {'period': '2025-01-24',
#   'currency_id': 'BND',
#   'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#   'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#   'buying_sight': '24.5576000',
#   'buying_transfer': '24.6476000',
#   'selling': '25.4074000',
#   'mid_rate': '25.0275000'},
#  {'period': '2025-01-24',
#   'currency_id': 'PHP',
#   'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#   'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#   'buying_sight': '0.5483000',
#   'buying_transfer': '0.5529000',
#   'selling': '0.5987000',
#   'mid_rate': '0.5758000'},
#  {'period': '2025-01-24',
#   'currency_id': 'IDR',
#   'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#   'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#   'buying_sight': '1.9207000',
#   'buying_transfer': '1.9959000',
#   'selling': '2.1891000',
#   'mid_rate': '2.0925000'},
#  {'period': '2025-01-24',
#   'currency_id': 'INR',
#   'currency_name_th': 'อินเดีย : รูปี (INR) ',
#   'currency_name_eng': 'INDIA : RUPEE (INR)',
#   'buying_sight': '0.3600000',
#   'buying_transfer': '0.3620000',
#   'selling': '0.4222000',
#   'mid_rate': '0.3921000'},
#  {'period': '2025-01-24',
#   'currency_id': 'CHF',
#   'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#   'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#   'buying_sight': '36.9470000',
#   'buying_transfer': '37.0376000',
#   'selling': '37.6638000',
#   'mid_rate': '37.3507000'},
#  {'period': '2025-01-24',
#   'currency_id': 'AUD',
#   'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#   'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#   'buying_sight': '20.8323000',
#   'buying_transfer': '20.9008000',
#   'selling': '21.6936000',
#   'mid_rate': '21.2972000'},
#  {'period': '2025-01-24',
#   'currency_id': 'NZD',
#   'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#   'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#   'buying_sight': '18.8775000',
#   'buying_transfer': '18.9386000',
#   'selling': '19.5579000',
#   'mid_rate': '19.2483000'},
#  {'period': '2025-01-24',
#   'currency_id': 'CAD',
#   'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#   'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#   'buying_sight': '23.2581000',
#   'buying_transfer': '23.3270000',
#   'selling': '23.8035000',
#   'mid_rate': '23.5653000'},
#  {'period': '2025-01-24',
#   'currency_id': 'SEK',
#   'currency_name_th': 'สวีเดน : โครนา (SEK)',
#   'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#   'buying_sight': '3.0346000',
#   'buying_transfer': '3.0491000',
#   'selling': '3.1089000',
#   'mid_rate': '3.0790000'},
#  {'period': '2025-01-24',
#   'currency_id': 'DKK',
#   'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#   'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#   'buying_sight': '4.6775000',
#   'buying_transfer': '4.6925000',
#   'selling': '4.7724000',
#   'mid_rate': '4.7325000'},
#  {'period': '2025-01-24',
#   'currency_id': 'NOK',
#   'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#   'currency_name_eng': 'NORWAY : KRONE (NOK)',
#   'buying_sight': '2.9605000',
#   'buying_transfer': '2.9724000',
#   'selling': '3.0377000',
#   'mid_rate': '3.0051000'},
#  {'period': '2025-01-24',
#   'currency_id': 'CNY',
#   'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#   'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#   'buying_sight': '4.5716000',
#   'buying_transfer': '4.5995000',
#   'selling': '4.7225000',
#   'mid_rate': '4.6610000'},
#  {'period': '2025-01-23',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '33.6759000',
#   'buying_transfer': '33.7636000',
#   'selling': '34.0863000',
#   'mid_rate': '33.9250000'},
#  {'period': '2025-01-23',
#   'currency_id': 'GBP',
#   'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#   'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#   'buying_sight': '41.2433000',
#   'buying_transfer': '41.3782000',
#   'selling': '42.1683000',
#   'mid_rate': '41.7733000'},
#  {'period': '2025-01-23',
#   'currency_id': 'EUR',
#   'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#   'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#   'buying_sight': '34.8514000',
#   'buying_transfer': '34.9548000',
#   'selling': '35.6231000',
#   'mid_rate': '35.2890000'},
#  {'period': '2025-01-23',
#   'currency_id': 'JPY',
#   'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#   'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#   'buying_sight': '21.2994000',
#   'buying_transfer': '21.3886000',
#   'selling': '22.0225000',
#   'mid_rate': '21.7056000'},
#  {'period': '2025-01-23',
#   'currency_id': 'HKD',
#   'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#   'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#   'buying_sight': '4.3016000',
#   'buying_transfer': '4.3177000',
#   'selling': '4.3957000',
#   'mid_rate': '4.3567000'},
#  {'period': '2025-01-23',
#   'currency_id': 'MYR',
#   'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#   'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#   'buying_sight': '7.4942000',
#   'buying_transfer': '7.5356000',
#   'selling': '7.7482000',
#   'mid_rate': '7.6419000'},
#  {'period': '2025-01-23',
#   'currency_id': 'SGD',
#   'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#   'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#   'buying_sight': '24.6849000',
#   'buying_transfer': '24.7538000',
#   'selling': '25.2993000',
#   'mid_rate': '25.0266000'},
#  {'period': '2025-01-23',
#   'currency_id': 'BND',
#   'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#   'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#   'buying_sight': '24.5774000',
#   'buying_transfer': '24.6674000',
#   'selling': '25.4237000',
#   'mid_rate': '25.0456000'},
#  {'period': '2025-01-23',
#   'currency_id': 'PHP',
#   'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#   'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#   'buying_sight': '0.5488000',
#   'buying_transfer': '0.5538000',
#   'selling': '0.6005000',
#   'mid_rate': '0.5772000'},
#  {'period': '2025-01-23',
#   'currency_id': 'IDR',
#   'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#   'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#   'buying_sight': '1.8940000',
#   'buying_transfer': '1.9893000',
#   'selling': '2.1936000',
#   'mid_rate': '2.0915000'},
#  {'period': '2025-01-23',
#   'currency_id': 'INR',
#   'currency_name_th': 'อินเดีย : รูปี (INR) ',
#   'currency_name_eng': 'INDIA : RUPEE (INR)',
#   'buying_sight': '0.3611000',
#   'buying_transfer': '0.3668000',
#   'selling': '0.4223000',
#   'mid_rate': '0.3946000'},
#  {'period': '2025-01-23',
#   'currency_id': 'CHF',
#   'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#   'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#   'buying_sight': '37.0201000',
#   'buying_transfer': '37.1124000',
#   'selling': '37.7404000',
#   'mid_rate': '37.4264000'},
#  {'period': '2025-01-23',
#   'currency_id': 'AUD',
#   'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#   'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#   'buying_sight': '20.7895000',
#   'buying_transfer': '20.8560000',
#   'selling': '21.6139000',
#   'mid_rate': '21.2350000'},
#  {'period': '2025-01-23',
#   'currency_id': 'NZD',
#   'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#   'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#   'buying_sight': '18.8367000',
#   'buying_transfer': '18.9040000',
#   'selling': '19.4930000',
#   'mid_rate': '19.1985000'},
#  {'period': '2025-01-23',
#   'currency_id': 'CAD',
#   'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#   'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#   'buying_sight': '23.2819000',
#   'buying_transfer': '23.3511000',
#   'selling': '23.8232000',
#   'mid_rate': '23.5872000'},
#  {'period': '2025-01-23',
#   'currency_id': 'SEK',
#   'currency_name_th': 'สวีเดน : โครนา (SEK)',
#   'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#   'buying_sight': '3.0345000',
#   'buying_transfer': '3.0492000',
#   'selling': '3.1118000',
#   'mid_rate': '3.0805000'},
#  {'period': '2025-01-23',
#   'currency_id': 'DKK',
#   'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#   'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#   'buying_sight': '4.6756000',
#   'buying_transfer': '4.6905000',
#   'selling': '4.7731000',
#   'mid_rate': '4.7318000'},
#  {'period': '2025-01-23',
#   'currency_id': 'NOK',
#   'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#   'currency_name_eng': 'NORWAY : KRONE (NOK)',
#   'buying_sight': '2.9545000',
#   'buying_transfer': '2.9666000',
#   'selling': '3.0343000',
#   'mid_rate': '3.0005000'},
#  {'period': '2025-01-23',
#   'currency_id': 'CNY',
#   'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#   'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#   'buying_sight': '4.5738000',
#   'buying_transfer': '4.6013000',
#   'selling': '4.7205000',
#   'mid_rate': '4.6609000'},
#  {'period': '2025-01-22',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '33.7300000',
#   'buying_transfer': '33.7934000',
#   'selling': '34.1071000',
#   'mid_rate': '33.9503000'},
#  {'period': '2025-01-22',
#   'currency_id': 'GBP',
#   'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#   'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#   'buying_sight': '41.2209000',
#   'buying_transfer': '41.3279000',
#   'selling': '42.0944000',
#   'mid_rate': '41.7112000'},
#  {'period': '2025-01-22',
#   'currency_id': 'EUR',
#   'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#   'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#   'buying_sight': '34.8396000',
#   'buying_transfer': '34.9215000',
#   'selling': '35.5579000',
#   'mid_rate': '35.2397000'},
#  {'period': '2025-01-22',
#   'currency_id': 'JPY',
#   'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#   'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#   'buying_sight': '21.4352000',
#   'buying_transfer': '21.5047000',
#   'selling': '22.1071000',
#   'mid_rate': '21.8059000'},
#  {'period': '2025-01-22',
#   'currency_id': 'HKD',
#   'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#   'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#   'buying_sight': '4.3195000',
#   'buying_transfer': '4.3337000',
#   'selling': '4.3901000',
#   'mid_rate': '4.3619000'},
#  {'period': '2025-01-22',
#   'currency_id': 'MYR',
#   'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#   'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#   'buying_sight': '7.4681000',
#   'buying_transfer': '7.5115000',
#   'selling': '7.7245000',
#   'mid_rate': '7.6180000'},
#  {'period': '2025-01-22',
#   'currency_id': 'SGD',
#   'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#   'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#   'buying_sight': '24.7032000',
#   'buying_transfer': '24.7632000',
#   'selling': '25.2771000',
#   'mid_rate': '25.0202000'},
#  {'period': '2025-01-22',
#   'currency_id': 'BND',
#   'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#   'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#   'buying_sight': '24.5626000',
#   'buying_transfer': '24.6526000',
#   'selling': '25.4043000',
#   'mid_rate': '25.0285000'},
#  {'period': '2025-01-22',
#   'currency_id': 'PHP',
#   'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#   'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#   'buying_sight': '0.5494000',
#   'buying_transfer': '0.5572000',
#   'selling': '0.5969000',
#   'mid_rate': '0.5771000'},
#  {'period': '2025-01-22',
#   'currency_id': 'IDR',
#   'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#   'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#   'buying_sight': '1.8932000',
#   'buying_transfer': '1.9790000',
#   'selling': '2.1867000',
#   'mid_rate': '2.0829000'},
#  {'period': '2025-01-22',
#   'currency_id': 'INR',
#   'currency_name_th': 'อินเดีย : รูปี (INR) ',
#   'currency_name_eng': 'INDIA : RUPEE (INR)',
#   'buying_sight': '0.3641000',
#   'buying_transfer': '0.3658000',
#   'selling': '0.4185000',
#   'mid_rate': '0.3922000'},
#  {'period': '2025-01-22',
#   'currency_id': 'CHF',
#   'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#   'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#   'buying_sight': '37.0375000',
#   'buying_transfer': '37.1071000',
#   'selling': '37.7244000',
#   'mid_rate': '37.4158000'},
#  {'period': '2025-01-22',
#   'currency_id': 'AUD',
#   'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#   'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#   'buying_sight': '20.7935000',
#   'buying_transfer': '20.8408000',
#   'selling': '21.5702000',
#   'mid_rate': '21.2055000'},
#  {'period': '2025-01-22',
#   'currency_id': 'NZD',
#   'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#   'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#   'buying_sight': '18.8173000',
#   'buying_transfer': '18.8780000',
#   'selling': '19.4368000',
#   'mid_rate': '19.1574000'},
#  {'period': '2025-01-22',
#   'currency_id': 'CAD',
#   'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#   'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#   'buying_sight': '23.3214000',
#   'buying_transfer': '23.3739000',
#   'selling': '23.8289000',
#   'mid_rate': '23.6014000'},
#  {'period': '2025-01-22',
#   'currency_id': 'SEK',
#   'currency_name_th': 'สวีเดน : โครนา (SEK)',
#   'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#   'buying_sight': '3.0303000',
#   'buying_transfer': '3.0428000',
#   'selling': '3.0930000',
#   'mid_rate': '3.0679000'},
#  {'period': '2025-01-22',
#   'currency_id': 'DKK',
#   'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#   'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#   'buying_sight': '4.6780000',
#   'buying_transfer': '4.6901000',
#   'selling': '4.7495000',
#   'mid_rate': '4.7198000'},
#  {'period': '2025-01-22',
#   'currency_id': 'NOK',
#   'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#   'currency_name_eng': 'NORWAY : KRONE (NOK)',
#   'buying_sight': '2.9462000',
#   'buying_transfer': '2.9571000',
#   'selling': '3.0104000',
#   'mid_rate': '2.9838000'},
#  {'period': '2025-01-22',
#   'currency_id': 'CNY',
#   'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#   'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#   'buying_sight': '4.6158000',
#   'buying_transfer': '4.6298000',
#   'selling': '4.7143000',
#   'mid_rate': '4.6721000'},
#  {'period': '2025-01-21',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '33.9285000',
#   'buying_transfer': '33.9911000',
#   'selling': '34.2975000',
#   'mid_rate': '34.1443000'},
#  {'period': '2025-01-21',
#   'currency_id': 'GBP',
#   'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#   'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#   'buying_sight': '41.3193000',
#   'buying_transfer': '41.4101000',
#   'selling': '42.1989000',
#   'mid_rate': '41.8045000'},
#  {'period': '2025-01-21',
#   'currency_id': 'EUR',
#   'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#   'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#   'buying_sight': '34.9163000',
#   'buying_transfer': '34.9998000',
#   'selling': '35.6684000',
#   'mid_rate': '35.3341000'},
#  {'period': '2025-01-21',
#   'currency_id': 'JPY',
#   'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#   'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#   'buying_sight': '21.5502000',
#   'buying_transfer': '21.6320000',
#   'selling': '22.2668000',
#   'mid_rate': '21.9494000'},
#  {'period': '2025-01-21',
#   'currency_id': 'HKD',
#   'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#   'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#   'buying_sight': '4.3473000',
#   'buying_transfer': '4.3618000',
#   'selling': '4.4217000',
#   'mid_rate': '4.3918000'},
#  {'period': '2025-01-21',
#   'currency_id': 'MYR',
#   'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#   'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#   'buying_sight': '7.4715000',
#   'buying_transfer': '7.5142000',
#   'selling': '7.7348000',
#   'mid_rate': '7.6245000'},
#  {'period': '2025-01-21',
#   'currency_id': 'SGD',
#   'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#   'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#   'buying_sight': '24.7591000',
#   'buying_transfer': '24.8195000',
#   'selling': '25.3588000',
#   'mid_rate': '25.0892000'},
#  {'period': '2025-01-21',
#   'currency_id': 'BND',
#   'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#   'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#   'buying_sight': '24.6122000',
#   'buying_transfer': '24.7022000',
#   'selling': '25.4568000',
#   'mid_rate': '25.0795000'},
#  {'period': '2025-01-21',
#   'currency_id': 'PHP',
#   'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#   'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#   'buying_sight': '0.5527000',
#   'buying_transfer': '0.5582000',
#   'selling': '0.6041000',
#   'mid_rate': '0.5812000'},
#  {'period': '2025-01-21',
#   'currency_id': 'IDR',
#   'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#   'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#   'buying_sight': '1.8966000',
#   'buying_transfer': '1.9926000',
#   'selling': '2.1913000',
#   'mid_rate': '2.0920000'},
#  {'period': '2025-01-21',
#   'currency_id': 'INR',
#   'currency_name_th': 'อินเดีย : รูปี (INR) ',
#   'currency_name_eng': 'INDIA : RUPEE (INR)',
#   'buying_sight': '0.3596000',
#   'buying_transfer': '0.3674000',
#   'selling': '0.4262000',
#   'mid_rate': '0.3968000'},
#  {'period': '2025-01-21',
#   'currency_id': 'CHF',
#   'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#   'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#   'buying_sight': '37.1146000',
#   'buying_transfer': '37.2046000',
#   'selling': '37.8225000',
#   'mid_rate': '37.5136000'},
#  {'period': '2025-01-21',
#   'currency_id': 'AUD',
#   'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#   'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#   'buying_sight': '20.8467000',
#   'buying_transfer': '20.9014000',
#   'selling': '21.6639000',
#   'mid_rate': '21.2827000'},
#  {'period': '2025-01-21',
#   'currency_id': 'NZD',
#   'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#   'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#   'buying_sight': '18.8543000',
#   'buying_transfer': '18.9120000',
#   'selling': '19.4952000',
#   'mid_rate': '19.2036000'},
#  {'period': '2025-01-21',
#   'currency_id': 'CAD',
#   'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#   'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#   'buying_sight': '23.3878000',
#   'buying_transfer': '23.4492000',
#   'selling': '23.9021000',
#   'mid_rate': '23.6757000'},
#  {'period': '2025-01-21',
#   'currency_id': 'SEK',
#   'currency_name_th': 'สวีเดน : โครนา (SEK)',
#   'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#   'buying_sight': '3.0327000',
#   'buying_transfer': '3.0442000',
#   'selling': '3.0927000',
#   'mid_rate': '3.0685000'},
#  {'period': '2025-01-21',
#   'currency_id': 'DKK',
#   'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#   'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#   'buying_sight': '4.6877000',
#   'buying_transfer': '4.6970000',
#   'selling': '4.7658000',
#   'mid_rate': '4.7314000'},
#  {'period': '2025-01-21',
#   'currency_id': 'NOK',
#   'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#   'currency_name_eng': 'NORWAY : KRONE (NOK)',
#   'buying_sight': '2.9597000',
#   'buying_transfer': '2.9704000',
#   'selling': '3.0217000',
#   'mid_rate': '2.9961000'},
#  {'period': '2025-01-21',
#   'currency_id': 'CNY',
#   'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#   'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#   'buying_sight': '4.6249000',
#   'buying_transfer': '4.6378000',
#   'selling': '4.7510000',
#   'mid_rate': '4.6944000'},
#  {'period': '2025-01-20',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '34.1336000',
#   'buying_transfer': '34.2307000',
#   'selling': '34.5615000',
#   'mid_rate': '34.3961000'},
#  {'period': '2025-01-20',
#   'currency_id': 'GBP',
#   'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#   'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#   'buying_sight': '41.4057000',
#   'buying_transfer': '41.5313000',
#   'selling': '42.3548000',
#   'mid_rate': '41.9431000'},
#  {'period': '2025-01-20',
#   'currency_id': 'EUR',
#   'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#   'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#   'buying_sight': '34.9454000',
#   'buying_transfer': '35.0586000',
#   'selling': '35.7404000',
#   'mid_rate': '35.3995000'},
#  {'period': '2025-01-20',
#   'currency_id': 'JPY',
#   'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#   'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#   'buying_sight': '21.6282000',
#   'buying_transfer': '21.7448000',
#   'selling': '22.3994000',
# ...
#   'buying_transfer': '3.0244000',
#   'selling': '3.0956000',
#   'mid_rate': '3.0600000'},
#  {'period': '2025-01-07',
#   'currency_id': 'CNY',
#   'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#   'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#   'buying_sight': '4.6182000',
#   'buying_transfer': '4.6500000',
#   'selling': '4.7821000',
#   'mid_rate': '4.7161000'},
#  {'period': '2025-01-06',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '34.3315000',
#   'buying_transfer': '34.4171000',
#   'selling': '34.7345000',
#   'mid_rate': '34.5758000'},
#  {'period': '2025-01-06',
#   'currency_id': 'GBP',
#   'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#   'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#   'buying_sight': '42.4916000',
#   'buying_transfer': '42.6176000',
#   'selling': '43.4211000',
#   'mid_rate': '43.0194000'},
#  {'period': '2025-01-06',
#   'currency_id': 'EUR',
#   'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#   'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#   'buying_sight': '35.2261000',
#   'buying_transfer': '35.3214000',
#   'selling': '35.9934000',
#   'mid_rate': '35.6574000'},
#  {'period': '2025-01-06',
#   'currency_id': 'JPY',
#   'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#   'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#   'buying_sight': '21.5220000',
#   'buying_transfer': '21.6166000',
#   'selling': '22.2635000',
#   'mid_rate': '21.9401000'},
#  {'period': '2025-01-06',
#   'currency_id': 'HKD',
#   'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#   'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#   'buying_sight': '4.3945000',
#   'buying_transfer': '4.4099000',
#   'selling': '4.4852000',
#   'mid_rate': '4.4476000'},
#  {'period': '2025-01-06',
#   'currency_id': 'MYR',
#   'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#   'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#   'buying_sight': '7.5264000',
#   'buying_transfer': '7.5670000',
#   'selling': '7.7891000',
#   'mid_rate': '7.6781000'},
#  {'period': '2025-01-06',
#   'currency_id': 'SGD',
#   'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#   'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#   'buying_sight': '24.9132000',
#   'buying_transfer': '24.9830000',
#   'selling': '25.5318000',
#   'mid_rate': '25.2574000'},
#  {'period': '2025-01-06',
#   'currency_id': 'BND',
#   'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#   'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#   'buying_sight': '24.8256000',
#   'buying_transfer': '24.9156000',
#   'selling': '25.6648000',
#   'mid_rate': '25.2902000'},
#  {'period': '2025-01-06',
#   'currency_id': 'PHP',
#   'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#   'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#   'buying_sight': '0.5627000',
#   'buying_transfer': '0.5686000',
#   'selling': '0.6140000',
#   'mid_rate': '0.5913000'},
#  {'period': '2025-01-06',
#   'currency_id': 'IDR',
#   'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#   'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#   'buying_sight': '1.9609000',
#   'buying_transfer': '2.0488000',
#   'selling': '2.2446000',
#   'mid_rate': '2.1467000'},
#  {'period': '2025-01-06',
#   'currency_id': 'INR',
#   'currency_name_th': 'อินเดีย : รูปี (INR) ',
#   'currency_name_eng': 'INDIA : RUPEE (INR)',
#   'buying_sight': '0.3706000',
#   'buying_transfer': '0.3765000',
#   'selling': '0.4339000',
#   'mid_rate': '0.4052000'},
#  {'period': '2025-01-06',
#   'currency_id': 'CHF',
#   'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#   'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#   'buying_sight': '37.6310000',
#   'buying_transfer': '37.7081000',
#   'selling': '38.3829000',
#   'mid_rate': '38.0455000'},
#  {'period': '2025-01-06',
#   'currency_id': 'AUD',
#   'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#   'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#   'buying_sight': '21.0850000',
#   'buying_transfer': '21.1465000',
#   'selling': '21.9362000',
#   'mid_rate': '21.5414000'},
#  {'period': '2025-01-06',
#   'currency_id': 'NZD',
#   'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#   'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#   'buying_sight': '19.0904000',
#   'buying_transfer': '19.1523000',
#   'selling': '19.7544000',
#   'mid_rate': '19.4534000'},
#  {'period': '2025-01-06',
#   'currency_id': 'CAD',
#   'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#   'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#   'buying_sight': '23.6805000',
#   'buying_transfer': '23.7458000',
#   'selling': '24.2647000',
#   'mid_rate': '24.0053000'},
#  {'period': '2025-01-06',
#   'currency_id': 'SEK',
#   'currency_name_th': 'สวีเดน : โครนา (SEK)',
#   'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#   'buying_sight': '3.0718000',
#   'buying_transfer': '3.0861000',
#   'selling': '3.1448000',
#   'mid_rate': '3.1155000'},
#  {'period': '2025-01-06',
#   'currency_id': 'DKK',
#   'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#   'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#   'buying_sight': '4.7312000',
#   'buying_transfer': '4.7452000',
#   'selling': '4.8235000',
#   'mid_rate': '4.7844000'},
#  {'period': '2025-01-06',
#   'currency_id': 'NOK',
#   'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#   'currency_name_eng': 'NORWAY : KRONE (NOK)',
#   'buying_sight': '3.0009000',
#   'buying_transfer': '3.0131000',
#   'selling': '3.0757000',
#   'mid_rate': '3.0444000'},
#  {'period': '2025-01-06',
#   'currency_id': 'CNY',
#   'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#   'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#   'buying_sight': '4.6250000',
#   'buying_transfer': '4.6510000',
#   'selling': '4.7695000',
#   'mid_rate': '4.7103000'},
#  {'period': '2025-01-03',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '34.1695000',
#   'buying_transfer': '34.2643000',
#   'selling': '34.5899000',
#   'mid_rate': '34.4271000'},
#  {'period': '2025-01-03',
#   'currency_id': 'GBP',
#   'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#   'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#   'buying_sight': '42.0920000',
#   'buying_transfer': '42.2366000',
#   'selling': '43.0656000',
#   'mid_rate': '42.6511000'},
#  {'period': '2025-01-03',
#   'currency_id': 'EUR',
#   'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#   'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#   'buying_sight': '34.8843000',
#   'buying_transfer': '34.9936000',
#   'selling': '35.6972000',
#   'mid_rate': '35.3454000'},
#  {'period': '2025-01-03',
#   'currency_id': 'JPY',
#   'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#   'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#   'buying_sight': '21.4522000',
#   'buying_transfer': '21.5567000',
#   'selling': '22.2343000',
#   'mid_rate': '21.8955000'},
#  {'period': '2025-01-03',
#   'currency_id': 'HKD',
#   'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#   'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#   'buying_sight': '4.3676000',
#   'buying_transfer': '4.3845000',
#   'selling': '4.4679000',
#   'mid_rate': '4.4262000'},
#  {'period': '2025-01-03',
#   'currency_id': 'MYR',
#   'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#   'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#   'buying_sight': '7.5193000',
#   'buying_transfer': '7.5577000',
#   'selling': '7.7752000',
#   'mid_rate': '7.6665000'},
#  {'period': '2025-01-03',
#   'currency_id': 'SGD',
#   'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#   'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#   'buying_sight': '24.7931000',
#   'buying_transfer': '24.8674000',
#   'selling': '25.4403000',
#   'mid_rate': '25.1539000'},
#  {'period': '2025-01-03',
#   'currency_id': 'BND',
#   'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#   'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#   'buying_sight': '24.6988000',
#   'buying_transfer': '24.7888000',
#   'selling': '25.5419000',
#   'mid_rate': '25.1654000'},
#  {'period': '2025-01-03',
#   'currency_id': 'PHP',
#   'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#   'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#   'buying_sight': '0.5613000',
#   'buying_transfer': '0.5673000',
#   'selling': '0.6140000',
#   'mid_rate': '0.5907000'},
#  {'period': '2025-01-03',
#   'currency_id': 'IDR',
#   'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#   'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#   'buying_sight': '1.9544000',
#   'buying_transfer': '2.0400000',
#   'selling': '2.2280000',
#   'mid_rate': '2.1340000'},
#  {'period': '2025-01-03',
#   'currency_id': 'INR',
#   'currency_name_th': 'อินเดีย : รูปี (INR) ',
#   'currency_name_eng': 'INDIA : RUPEE (INR)',
#   'buying_sight': '0.3731000',
#   'buying_transfer': '0.3766000',
#   'selling': '0.4356000',
#   'mid_rate': '0.4061000'},
#  {'period': '2025-01-03',
#   'currency_id': 'CHF',
#   'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#   'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#   'buying_sight': '37.3168000',
#   'buying_transfer': '37.4103000',
#   'selling': '38.1130000',
#   'mid_rate': '37.7617000'},
#  {'period': '2025-01-03',
#   'currency_id': 'AUD',
#   'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#   'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#   'buying_sight': '20.8888000',
#   'buying_transfer': '20.9585000',
#   'selling': '21.7799000',
#   'mid_rate': '21.3692000'},
#  {'period': '2025-01-03',
#   'currency_id': 'NZD',
#   'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#   'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#   'buying_sight': '18.9077000',
#   'buying_transfer': '18.9789000',
#   'selling': '19.5988000',
#   'mid_rate': '19.2889000'},
#  {'period': '2025-01-03',
#   'currency_id': 'CAD',
#   'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#   'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#   'buying_sight': '23.5547000',
#   'buying_transfer': '23.6320000',
#   'selling': '24.1706000',
#   'mid_rate': '23.9013000'},
#  {'period': '2025-01-03',
#   'currency_id': 'SEK',
#   'currency_name_th': 'สวีเดน : โครนา (SEK)',
#   'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#   'buying_sight': '3.0397000',
#   'buying_transfer': '3.0551000',
#   'selling': '3.1216000',
#   'mid_rate': '3.0884000'},
#  {'period': '2025-01-03',
#   'currency_id': 'DKK',
#   'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#   'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#   'buying_sight': '4.6785000',
#   'buying_transfer': '4.6944000',
#   'selling': '4.7858000',
#   'mid_rate': '4.7401000'},
#  {'period': '2025-01-03',
#   'currency_id': 'NOK',
#   'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#   'currency_name_eng': 'NORWAY : KRONE (NOK)',
#   'buying_sight': '2.9726000',
#   'buying_transfer': '2.9854000',
#   'selling': '3.0577000',
#   'mid_rate': '3.0216000'},
#  {'period': '2025-01-03',
#   'currency_id': 'CNY',
#   'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#   'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#   'buying_sight': '4.6052000',
#   'buying_transfer': '4.6372000',
#   'selling': '4.7713000',
#   'mid_rate': '4.7043000'},
#  {'period': '2025-01-02',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '33.9631000',
#   'buying_transfer': '34.0420000',
#   'selling': '34.3667000',
#   'mid_rate': '34.2044000'},
#  {'period': '2025-01-02',
#   'currency_id': 'GBP',
#   'currency_name_th': 'อังกฤษ : ปอนด์สเตอร์ลิง (GBP)',
#   'currency_name_eng': 'UNITED KINGDOM : POUND STERING (GBP)',
#   'buying_sight': '42.3259000',
#   'buying_transfer': '42.4359000',
#   'selling': '43.2382000',
#   'mid_rate': '42.8371000'},
#  {'period': '2025-01-02',
#   'currency_id': 'EUR',
#   'currency_name_th': 'ยูโรโซน : ยูโร (EUR)',
#   'currency_name_eng': 'EURO ZONE : EURO (EUR)',
#   'buying_sight': '35.0109000',
#   'buying_transfer': '35.0865000',
#   'selling': '35.7634000',
#   'mid_rate': '35.4250000'},
#  {'period': '2025-01-02',
#   'currency_id': 'JPY',
#   'currency_name_th': 'ญี่ปุ่น : เยน (100 เยน) (JPY)',
#   'currency_name_eng': 'JAPAN : YEN (100 YEN) (JPY) ',
#   'buying_sight': '21.3616000',
#   'buying_transfer': '21.4332000',
#   'selling': '22.0794000',
#   'mid_rate': '21.7563000'},
#  {'period': '2025-01-02',
#   'currency_id': 'HKD',
#   'currency_name_th': 'ฮ่องกง : ดอลลาร์ (HKD) ',
#   'currency_name_eng': 'HONG KONG : DOLLAR (HKD)',
#   'buying_sight': '4.3498000',
#   'buying_transfer': '4.3651000',
#   'selling': '4.4349000',
#   'mid_rate': '4.4000000'},
#  {'period': '2025-01-02',
#   'currency_id': 'MYR',
#   'currency_name_th': 'มาเลเซีย : ริงกิต (MYR)',
#   'currency_name_eng': 'MALAYSIA : RINGGIT (MYR)',
#   'buying_sight': '7.4907000',
#   'buying_transfer': '7.5304000',
#   'selling': '7.7525000',
#   'mid_rate': '7.6415000'},
#  {'period': '2025-01-02',
#   'currency_id': 'SGD',
#   'currency_name_th': 'สิงคโปร์ : ดอลลาร์ (SGD) ',
#   'currency_name_eng': 'SINGAPORE : DOLLAR (SGD)',
#   'buying_sight': '24.7696000',
#   'buying_transfer': '24.8323000',
#   'selling': '25.3767000',
#   'mid_rate': '25.1045000'},
#  {'period': '2025-01-02',
#   'currency_id': 'BND',
#   'currency_name_th': 'บรูไนดารุสซาลาม : ดอลลาร์ (BND)',
#   'currency_name_eng': 'BRUNEI : DOLLAR (BND) ',
#   'buying_sight': '24.6391000',
#   'buying_transfer': '24.7291000',
#   'selling': '25.4706000',
#   'mid_rate': '25.0999000'},
#  {'period': '2025-01-02',
#   'currency_id': 'PHP',
#   'currency_name_th': 'ฟิลิปปินส์ : เปโซ (PHP) ',
#   'currency_name_eng': 'PHILIPPINES : PESO (PHP) ',
#   'buying_sight': '0.5600000',
#   'buying_transfer': '0.5667000',
#   'selling': '0.6117000',
#   'mid_rate': '0.5892000'},
#  {'period': '2025-01-02',
#   'currency_id': 'IDR',
#   'currency_name_th': 'อินโดนิเซีย : รูเปีย (1,000 รูเปีย) (IDR)',
#   'currency_name_eng': 'INDONESIA : RUPIAH (1,000 RUPIAH) (IDR)',
#   'buying_sight': '1.9459000',
#   'buying_transfer': '2.0309000',
#   'selling': '2.2243000',
#   'mid_rate': '2.1276000'},
#  {'period': '2025-01-02',
#   'currency_id': 'INR',
#   'currency_name_th': 'อินเดีย : รูปี (INR) ',
#   'currency_name_eng': 'INDIA : RUPEE (INR)',
#   'buying_sight': '0.3717000',
#   'buying_transfer': '0.3782000',
#   'selling': '0.4339000',
#   'mid_rate': '0.4061000'},
#  {'period': '2025-01-02',
#   'currency_id': 'CHF',
#   'currency_name_th': 'สวิสเซอร์แลนด์ : ฟรังก์ (CHF)',
#   'currency_name_eng': 'SWITZERLAND : FRANC (CHF) ',
#   'buying_sight': '37.3788000',
#   'buying_transfer': '37.4404000',
#   'selling': '38.1119000',
#   'mid_rate': '37.7762000'},
#  {'period': '2025-01-02',
#   'currency_id': 'AUD',
#   'currency_name_th': 'ออสเตรเลีย : ดอลลาร์ (AUD)',
#   'currency_name_eng': 'AUSTRALIA : DOLLAR (AUD) ',
#   'buying_sight': '20.8074000',
#   'buying_transfer': '20.8432000',
#   'selling': '21.6385000',
#   'mid_rate': '21.2409000'},
#  {'period': '2025-01-02',
#   'currency_id': 'NZD',
#   'currency_name_th': 'นิวซีแลนด์ : ดอลลาร์ (NZD)',
#   'currency_name_eng': 'NEW ZEALAND : DOLLAR (NZD)',
#   'buying_sight': '18.8425000',
#   'buying_transfer': '18.9054000',
#   'selling': '19.4933000',
#   'mid_rate': '19.1994000'},
#  {'period': '2025-01-02',
#   'currency_id': 'CAD',
#   'currency_name_th': 'แคนาดา : ดอลลาร์ (CAD)',
#   'currency_name_eng': 'CANADA : DOLLAR (CAD)',
#   'buying_sight': '23.4831000',
#   'buying_transfer': '23.5332000',
#   'selling': '24.0778000',
#   'mid_rate': '23.8055000'},
#  {'period': '2025-01-02',
#   'currency_id': 'SEK',
#   'currency_name_th': 'สวีเดน : โครนา (SEK)',
#   'currency_name_eng': 'SWEDEN : KRONA (SEK)',
#   'buying_sight': '3.0510000',
#   'buying_transfer': '3.0645000',
#   'selling': '3.1210000',
#   'mid_rate': '3.0928000'},
#  {'period': '2025-01-02',
#   'currency_id': 'DKK',
#   'currency_name_th': 'เดนมาร์ก : โครน (DKK)',
#   'currency_name_eng': 'DENMARK : KRONE (DKK) ',
#   'buying_sight': '4.7038000',
#   'buying_transfer': '4.7173000',
#   'selling': '4.7892000',
#   'mid_rate': '4.7533000'},
#  {'period': '2025-01-02',
#   'currency_id': 'NOK',
#   'currency_name_th': 'นอร์เวย์ : โครน (NOK) ',
#   'currency_name_eng': 'NORWAY : KRONE (NOK)',
#   'buying_sight': '2.9661000',
#   'buying_transfer': '2.9779000',
#   'selling': '3.0379000',
#   'mid_rate': '3.0079000'},
#  {'period': '2025-01-02',
#   'currency_id': 'CNY',
#   'currency_name_th': 'จีน : หยวน เรนมินบิ (CNY)',
#   'currency_name_eng': 'CHINA : YUAN RENMINBI (CNY)',
#   'buying_sight': '4.6004000',
#   'buying_transfer': '4.6225000',
#   'selling': '4.7306000',
#   'mid_rate': '4.6766000'}]

# %%
import pandas as pd

def fetch_exchange_rate(currency="USD", years=10, save_csv=True, filename="exchange_rate.csv"):
    headers = {"Authorization": f"Bearer {api_key}", "accept": "application/json"}

    url = "https://gateway.api.bot.or.th/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/"

    end_date = datetime.today()
    start_date = end_date - timedelta(days=years*365)

    current_start = start_date
    records = []

    # loop over 31 days time frame
    while current_start < end_date:
        # Calculate chunk end date
        current_end = min(current_start + timedelta(days=30), end_date)

        # Format dates for API
        start_str = current_start.strftime("%Y-%m-%d")
        end_str = current_end.strftime("%Y-%m-%d")

        print(f"Fetching {start_str} → {end_str} ...")

        # Call API with query parameters
        params = {
            "start_period": start_str,
            "end_period": end_str,
            "currency": currency
        }
        
        response = requests.get(url, headers=headers, params=params)

        if response.status_code == 200:
            data = response.json()
            if "result" in data and "data" in data["result"]:
                details = data["result"]["data"]["data_detail"]
                records.extend(details)
            else:
                print("no data found")
        else:
            print(f"error {response.status_code}: {response.text}")

        # next time frame
        current_start = current_end + timedelta(days=1)

    df = pd.DataFrame(records)

    if not df.empty:
        for col in ["buying_sight", "buying_transfer", "selling", "mid_rate"]:
            df[col] = pd.to_numeric(df[col], errors="coerce")

        df["period"] = pd.to_datetime(df["period"])
    else:
        print("no records!")
    return df

df = fetch_exchange_rate(currency="USD", years=10)
# Out:
# Fetching 2015-10-22 → 2015-11-21 ...
# Fetching 2015-11-22 → 2015-12-22 ...
# Fetching 2015-12-23 → 2016-01-22 ...
# Fetching 2016-01-23 → 2016-02-22 ...
# Fetching 2016-02-23 → 2016-03-24 ...
# Fetching 2016-03-25 → 2016-04-24 ...
# Fetching 2016-04-25 → 2016-05-25 ...
# Fetching 2016-05-26 → 2016-06-25 ...
# Fetching 2016-06-26 → 2016-07-26 ...
# Fetching 2016-07-27 → 2016-08-26 ...
# Fetching 2016-08-27 → 2016-09-26 ...
# Fetching 2016-09-27 → 2016-10-27 ...
# Fetching 2016-10-28 → 2016-11-27 ...
# Fetching 2016-11-28 → 2016-12-28 ...
# Fetching 2016-12-29 → 2017-01-28 ...
# Fetching 2017-01-29 → 2017-02-28 ...
# Fetching 2017-03-01 → 2017-03-31 ...
# Fetching 2017-04-01 → 2017-05-01 ...
# Fetching 2017-05-02 → 2017-06-01 ...
# Fetching 2017-06-02 → 2017-07-02 ...
# Fetching 2017-07-03 → 2017-08-02 ...
# Fetching 2017-08-03 → 2017-09-02 ...
# Fetching 2017-09-03 → 2017-10-03 ...
# Fetching 2017-10-04 → 2017-11-03 ...
# Fetching 2017-11-04 → 2017-12-04 ...
# Fetching 2017-12-05 → 2018-01-04 ...
# Fetching 2018-01-05 → 2018-02-04 ...
# Fetching 2018-02-05 → 2018-03-07 ...
# Fetching 2018-03-08 → 2018-04-07 ...
# Fetching 2018-04-08 → 2018-05-08 ...
# Fetching 2018-05-09 → 2018-06-08 ...
# Fetching 2018-06-09 → 2018-07-09 ...
# Fetching 2018-07-10 → 2018-08-09 ...
# Fetching 2018-08-10 → 2018-09-09 ...
# Fetching 2018-09-10 → 2018-10-10 ...
# Fetching 2018-10-11 → 2018-11-10 ...
# Fetching 2018-11-11 → 2018-12-11 ...
# Fetching 2018-12-12 → 2019-01-11 ...
# Fetching 2019-01-12 → 2019-02-11 ...
# Fetching 2019-02-12 → 2019-03-14 ...
# Fetching 2019-03-15 → 2019-04-14 ...
# Fetching 2019-04-15 → 2019-05-15 ...
# Fetching 2019-05-16 → 2019-06-15 ...
# Fetching 2019-06-16 → 2019-07-16 ...
# Fetching 2019-07-17 → 2019-08-16 ...
# Fetching 2019-08-17 → 2019-09-16 ...
# Fetching 2019-09-17 → 2019-10-17 ...
# Fetching 2019-10-18 → 2019-11-17 ...
# Fetching 2019-11-18 → 2019-12-18 ...
# Fetching 2019-12-19 → 2020-01-18 ...
# Fetching 2020-01-19 → 2020-02-18 ...
# Fetching 2020-02-19 → 2020-03-20 ...
# Fetching 2020-03-21 → 2020-04-20 ...
# Fetching 2020-04-21 → 2020-05-21 ...
# Fetching 2020-05-22 → 2020-06-21 ...
# Fetching 2020-06-22 → 2020-07-22 ...
# Fetching 2020-07-23 → 2020-08-22 ...
# Fetching 2020-08-23 → 2020-09-22 ...
# Fetching 2020-09-23 → 2020-10-23 ...
# Fetching 2020-10-24 → 2020-11-23 ...
# Fetching 2020-11-24 → 2020-12-24 ...
# Fetching 2020-12-25 → 2021-01-24 ...
# Fetching 2021-01-25 → 2021-02-24 ...
# Fetching 2021-02-25 → 2021-03-27 ...
# Fetching 2021-03-28 → 2021-04-27 ...
# Fetching 2021-04-28 → 2021-05-28 ...
# Fetching 2021-05-29 → 2021-06-28 ...
# Fetching 2021-06-29 → 2021-07-29 ...
# Fetching 2021-07-30 → 2021-08-29 ...
# Fetching 2021-08-30 → 2021-09-29 ...
# Fetching 2021-09-30 → 2021-10-30 ...
# Fetching 2021-10-31 → 2021-11-30 ...
# Fetching 2021-12-01 → 2021-12-31 ...
# Fetching 2022-01-01 → 2022-01-31 ...
# Fetching 2022-02-01 → 2022-03-03 ...
# Fetching 2022-03-04 → 2022-04-03 ...
# Fetching 2022-04-04 → 2022-05-04 ...
# Fetching 2022-05-05 → 2022-06-04 ...
# Fetching 2022-06-05 → 2022-07-05 ...
# Fetching 2022-07-06 → 2022-08-05 ...
# Fetching 2022-08-06 → 2022-09-05 ...
# Fetching 2022-09-06 → 2022-10-06 ...
# Fetching 2022-10-07 → 2022-11-06 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2022-11-07 → 2022-12-07 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2022-12-08 → 2023-01-07 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2023-01-08 → 2023-02-07 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2023-02-08 → 2023-03-10 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2023-03-11 → 2023-04-10 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2023-04-11 → 2023-05-11 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2023-05-12 → 2023-06-11 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2023-06-12 → 2023-07-12 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2023-07-13 → 2023-08-12 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2023-08-13 → 2023-09-12 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2023-09-13 → 2023-10-13 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2023-10-14 → 2023-11-13 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2023-11-14 → 2023-12-14 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2023-12-15 → 2024-01-14 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2024-01-15 → 2024-02-14 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2024-02-15 → 2024-03-16 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2024-03-17 → 2024-04-16 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2024-04-17 → 2024-05-17 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2024-05-18 → 2024-06-17 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2024-06-18 → 2024-07-18 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2024-07-19 → 2024-08-18 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2024-08-19 → 2024-09-18 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2024-09-19 → 2024-10-19 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2024-10-20 → 2024-11-19 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2024-11-20 → 2024-12-20 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2024-12-21 → 2025-01-20 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2025-01-21 → 2025-02-20 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2025-02-21 → 2025-03-23 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2025-03-24 → 2025-04-23 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2025-04-24 → 2025-05-24 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2025-05-25 → 2025-06-24 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2025-06-25 → 2025-07-25 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2025-07-26 → 2025-08-25 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2025-08-26 → 2025-09-25 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }
# Fetching 2025-09-26 → 2025-10-19 ...
# error 429: {
#     "error": "Rate Limit Exceeded"
# }

# %%
# i did save data from my very previous attempt so pls imagine that it works THANKS 
df.to_csv("../data/exchange_rate_usd", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 df.to_csv("../data/exchange_rate_usd", index=False)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
def fetch_weighted_exchange_rate(currency="USD", years=10, save_csv=True, filename="exchange_rate.csv"):
    headers = {"Authorization": f"Bearer {api_key}", "accept": "application/json"}

    url = "https://gateway.api.bot.or.th/Stat-ReferenceRate/v2/DAILY_REF_RATE/"

    end_date = datetime.today()
    start_date = end_date - timedelta(days=years*365)

    current_start = start_date
    records = []

    # loop over 31 days time frame
    while current_start < end_date:
        # Calculate chunk end date
        current_end = min(current_start + timedelta(days=30), end_date)

        # Format dates for API
        start_str = current_start.strftime("%Y-%m-%d")
        end_str = current_end.strftime("%Y-%m-%d")

        print(f"Fetching {start_str} → {end_str} ...")

        # Call API with query parameters
        params = {
            "start_period": start_str,
            "end_period": end_str,
            "currency": currency
        }
        
        response = requests.get(url, headers=headers, params=params)

        if response.status_code == 200:
            data = response.json()
            if "result" in data and "data" in data["result"]:
                details = data["result"]["data"]["data_detail"]
                records.extend(details)
            else:
                print("no data found")
        else:
            print(f"error {response.status_code}: {response.text}")

        # next time frame
        current_start = current_end + timedelta(days=1)

    df = pd.DataFrame(records)

    if not df.empty:
        df["rate"] = pd.to_numeric(df["rate"], errors="coerce")
        df["period"] = pd.to_datetime(df["period"])
    else:
        print("no records!")
    return df

df2 = fetch_weighted_exchange_rate(currency="USD", years=10)
# Out:
# Fetching 2015-10-24 → 2015-11-23 ...
# Fetching 2015-11-24 → 2015-12-24 ...
# Fetching 2015-12-25 → 2016-01-24 ...
# Fetching 2016-01-25 → 2016-02-24 ...
# Fetching 2016-02-25 → 2016-03-26 ...
# Fetching 2016-03-27 → 2016-04-26 ...
# Fetching 2016-04-27 → 2016-05-27 ...
# Fetching 2016-05-28 → 2016-06-27 ...
# Fetching 2016-06-28 → 2016-07-28 ...
# Fetching 2016-07-29 → 2016-08-28 ...
# Fetching 2016-08-29 → 2016-09-28 ...
# Fetching 2016-09-29 → 2016-10-29 ...
# Fetching 2016-10-30 → 2016-11-29 ...
# Fetching 2016-11-30 → 2016-12-30 ...
# Fetching 2016-12-31 → 2017-01-30 ...
# Fetching 2017-01-31 → 2017-03-02 ...
# Fetching 2017-03-03 → 2017-04-02 ...
# Fetching 2017-04-03 → 2017-05-03 ...
# Fetching 2017-05-04 → 2017-06-03 ...
# Fetching 2017-06-04 → 2017-07-04 ...
# Fetching 2017-07-05 → 2017-08-04 ...
# Fetching 2017-08-05 → 2017-09-04 ...
# Fetching 2017-09-05 → 2017-10-05 ...
# Fetching 2017-10-06 → 2017-11-05 ...
# Fetching 2017-11-06 → 2017-12-06 ...
# Fetching 2017-12-07 → 2018-01-06 ...
# Fetching 2018-01-07 → 2018-02-06 ...
# Fetching 2018-02-07 → 2018-03-09 ...
# Fetching 2018-03-10 → 2018-04-09 ...
# Fetching 2018-04-10 → 2018-05-10 ...
# Fetching 2018-05-11 → 2018-06-10 ...
# Fetching 2018-06-11 → 2018-07-11 ...
# Fetching 2018-07-12 → 2018-08-11 ...
# Fetching 2018-08-12 → 2018-09-11 ...
# Fetching 2018-09-12 → 2018-10-12 ...
# Fetching 2018-10-13 → 2018-11-12 ...
# Fetching 2018-11-13 → 2018-12-13 ...
# Fetching 2018-12-14 → 2019-01-13 ...
# Fetching 2019-01-14 → 2019-02-13 ...
# Fetching 2019-02-14 → 2019-03-16 ...
# Fetching 2019-03-17 → 2019-04-16 ...
# Fetching 2019-04-17 → 2019-05-17 ...
# Fetching 2019-05-18 → 2019-06-17 ...
# Fetching 2019-06-18 → 2019-07-18 ...
# Fetching 2019-07-19 → 2019-08-18 ...
# Fetching 2019-08-19 → 2019-09-18 ...
# Fetching 2019-09-19 → 2019-10-19 ...
# Fetching 2019-10-20 → 2019-11-19 ...
# Fetching 2019-11-20 → 2019-12-20 ...
# Fetching 2019-12-21 → 2020-01-20 ...
# Fetching 2020-01-21 → 2020-02-20 ...
# Fetching 2020-02-21 → 2020-03-22 ...
# Fetching 2020-03-23 → 2020-04-22 ...
# Fetching 2020-04-23 → 2020-05-23 ...
# Fetching 2020-05-24 → 2020-06-23 ...
# Fetching 2020-06-24 → 2020-07-24 ...
# Fetching 2020-07-25 → 2020-08-24 ...
# Fetching 2020-08-25 → 2020-09-24 ...
# Fetching 2020-09-25 → 2020-10-25 ...
# Fetching 2020-10-26 → 2020-11-25 ...
# Fetching 2020-11-26 → 2020-12-26 ...
# Fetching 2020-12-27 → 2021-01-26 ...
# Fetching 2021-01-27 → 2021-02-26 ...
# Fetching 2021-02-27 → 2021-03-29 ...
# Fetching 2021-03-30 → 2021-04-29 ...
# Fetching 2021-04-30 → 2021-05-30 ...
# Fetching 2021-05-31 → 2021-06-30 ...
# Fetching 2021-07-01 → 2021-07-31 ...
# Fetching 2021-08-01 → 2021-08-31 ...
# Fetching 2021-09-01 → 2021-10-01 ...
# Fetching 2021-10-02 → 2021-11-01 ...
# Fetching 2021-11-02 → 2021-12-02 ...
# Fetching 2021-12-03 → 2022-01-02 ...
# Fetching 2022-01-03 → 2022-02-02 ...
# Fetching 2022-02-03 → 2022-03-05 ...
# Fetching 2022-03-06 → 2022-04-05 ...
# Fetching 2022-04-06 → 2022-05-06 ...
# Fetching 2022-05-07 → 2022-06-06 ...
# Fetching 2022-06-07 → 2022-07-07 ...
# Fetching 2022-07-08 → 2022-08-07 ...
# Fetching 2022-08-08 → 2022-09-07 ...
# Fetching 2022-09-08 → 2022-10-08 ...
# Fetching 2022-10-09 → 2022-11-08 ...
# Fetching 2022-11-09 → 2022-12-09 ...
# Fetching 2022-12-10 → 2023-01-09 ...
# Fetching 2023-01-10 → 2023-02-09 ...
# Fetching 2023-02-10 → 2023-03-12 ...
# Fetching 2023-03-13 → 2023-04-12 ...
# Fetching 2023-04-13 → 2023-05-13 ...
# Fetching 2023-05-14 → 2023-06-13 ...
# Fetching 2023-06-14 → 2023-07-14 ...
# Fetching 2023-07-15 → 2023-08-14 ...
# Fetching 2023-08-15 → 2023-09-14 ...
# Fetching 2023-09-15 → 2023-10-15 ...
# Fetching 2023-10-16 → 2023-11-15 ...
# Fetching 2023-11-16 → 2023-12-16 ...
# Fetching 2023-12-17 → 2024-01-16 ...
# Fetching 2024-01-17 → 2024-02-16 ...
# Fetching 2024-02-17 → 2024-03-18 ...
# Fetching 2024-03-19 → 2024-04-18 ...
# Fetching 2024-04-19 → 2024-05-19 ...
# Fetching 2024-05-20 → 2024-06-19 ...
# Fetching 2024-06-20 → 2024-07-20 ...
# Fetching 2024-07-21 → 2024-08-20 ...
# Fetching 2024-08-21 → 2024-09-20 ...
# Fetching 2024-09-21 → 2024-10-21 ...
# Fetching 2024-10-22 → 2024-11-21 ...
# Fetching 2024-11-22 → 2024-12-22 ...
# Fetching 2024-12-23 → 2025-01-22 ...
# Fetching 2025-01-23 → 2025-02-22 ...
# Fetching 2025-02-23 → 2025-03-25 ...
# Fetching 2025-03-26 → 2025-04-25 ...
# Fetching 2025-04-26 → 2025-05-26 ...
# Fetching 2025-05-27 → 2025-06-26 ...
# Fetching 2025-06-27 → 2025-07-27 ...
# Fetching 2025-07-28 → 2025-08-27 ...
# Fetching 2025-08-28 → 2025-09-27 ...
# Fetching 2025-09-28 → 2025-10-21 ...

# %%
df2.to_csv("../data/weighted_exchange_rate_usd", index=False)

# %%
df2
# Out:
#          period    rate
# 0    2015-11-23  35.824
# 1    2015-11-20  35.713
# 2    2015-11-19  35.926
# 3    2015-11-18  36.041
# 4    2015-11-17  35.965
# ...         ...     ...
# 2424 2025-10-03  32.436
# 2425 2025-10-02  32.429
# 2426 2025-10-01  32.444
# 2427 2025-09-30  32.328
# 2428 2025-09-29  32.241
#
# [2429 rows x 2 columns]
