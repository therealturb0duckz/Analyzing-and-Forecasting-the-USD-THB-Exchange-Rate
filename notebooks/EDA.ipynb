# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# average exchange rate
df_avg = pd.read_csv("../data/average_exchange_rate.csv")

# %%
df_avg
# the 10-year period exchange rate only contains 2,430 rows due to weekends being excluded
# Out:
#           period currency_id              currency_name_th  \
# 0     2015-11-20         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)
# 1     2015-11-19         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)
# 2     2015-11-18         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)
# 3     2015-11-17         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)
# 4     2015-11-16         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)
# ...          ...         ...                           ...
# 2425  2025-10-01         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)
# 2426  2025-09-30         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)
# 2427  2025-09-29         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)
# 2428  2025-09-26         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)
# 2429  2025-09-25         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)
#
#         currency_name_eng  buying_sight  buying_transfer  selling  mid_rate
# 0     USA : DOLLAR (USD)        35.4844          35.5783  35.8992   35.7388
# 1     USA : DOLLAR (USD)        35.6730          35.7653  36.0900   35.9277
# ...

# %%
# weighted-average interbank 
df= pd.read_csv("../data/exchange_rate.csv")
